# %% [markdown]
# <center><h1>Data Curation and NLP - Big Data Technology</h1><br /></center>
# <center>Tutorial 3 - Fred Amouzgar</center>

# %% [markdown]
# <centre><img src="https://github.com/FredAmouzgar/BigData/blob/master/pics/NLP_wordmap.jpg?raw=true"></centre>

# %% [markdown]
# <h3>NLP Libraries in Python (data pre-processing, Tokenisation and Curation)</h3><br />
# 1- NLTK: the most widely-mentioned NLP library<br />
# 2- SpaCy:  an industrial-strength NLP library built for performance<br />
# 3- Stanford CoreNLP: Written in Java with Python Wrapper, well-known for its speed<br />
# 4- TextBlob: a user-friendly and intuitive NLTK interface<br />
# 5- Polyglot: an open-source NLP library<br />

# %% [markdown]
# <centre><img src="https://github.com/FredAmouzgar/BigData/blob/master/pics/NLTK.png?raw=true"></centre>

# %% [markdown]
# <h3>NLTK – Natural Language ToolKit</h3><br />
# The most popular Python NLP library
# It is a suite of libraries for statistical and symbolic Natural Language Processing
# NLTK is mostly an educational and research tool
# Good for Prototyping and Heavy for production
# Relevant Libraries:
# - Lexical Analysis: Word and Text Tokeniser
# - Part of Speech Tagger (POS tagging): Grammatical tagging and word-category
# - Name Entity Recognition (NER): Locate and classify named entities in text into pre-defined categories such as the names of persons, organizations, locations, expressions of times, quantities, monetary values, percentages

# %% [markdown]
# <centre><img src="https://github.com/FredAmouzgar/BigData/blob/master/pics/nlu_nlp.png?raw=true" width="600px" height="300px"></centre>

# %% [markdown]
# <h3>NLTK Installation</h3><br />
# - Find the Anaconda installation diresctory (Python and pip are usually under Scripts folder)<br />
# - Use pip/conda commands to install NLTK<br />
# - Then, download corpus and components as it is shown below<br />
# <centre><img src="https://github.com/FredAmouzgar/BigData/blob/master/pics/nltk_install.png?raw=true"></centre>

# %% [markdown]
# <h3>NLTK Tokenization</h3>

# %%
from nltk import sent_tokenize, word_tokenize
from nltk.tokenize  import  TreebankWordTokenizer, RegexpTokenizer

sentence1 = "This is a normal sentence. This is the second sentence."
word_list = word_tokenize(sentence1)  # Returns a list of words
sents = sent_tokenize(sentence1) # Returns a list of sentences
print(sents, " has ", len(sents), " elements.")

sentence2 = "That's a good dog."
tokenizer = TreebankWordTokenizer()
sent2_words = tokenizer.tokenize(sentence2) # Returns a list like this: ['That', "'s", 'a', 'good', 'dog', '.’]
print(sent2_words, " has ", len(sent2_words), " elements.")

sentence3 = "This/is-a.very+badly)formatted,,sentence…"
regex_tokenizer = RegexpTokenizer(r'\w+') # Dropping everything but alphanumerics
sent3_words = regex_tokenizer.tokenize(sentence3) # Returns a list of words, discarding all the other chars.
print(sent3_words, " has ", len(sent3_words), " elements.")
# Out:
# ['This is a normal sentence.', 'This is the second sentence.']  has  2  elements.
# ['That', "'s", 'a', 'good', 'dog', '.']  has  6  elements.
# ['This', 'is', 'a', 'very', 'badly', 'formatted', 'sentence']  has  7  elements.

# %% [markdown]
# <h3>NLTK – Part-of-Speech (POS) Tagging</h3>

# %%
import  nltk
comment = "Fit my galaxy s2 perfectly even with the case on it. Comfortable enough to wear and can still use the screen through the plastic"
text = nltk.word_tokenize(comment)
p_tags = nltk.pos_tag(text)  # The MAIN tagger
csv=""
for e in p_tags:
    print(e)
    if(e[1]=='NN'):
        if(csv==""):
            csv=e[0]
        else:
            csv+=","+e[0]
csv  # Consists of a comma-separated string:
# 'galaxy,s2,case,screen,plastic'
# Out:
# ('Fit', 'NNP')
# ('my', 'PRP$')
# ('galaxy', 'NN')
# ('s2', 'NN')
# ('perfectly', 'RB')
# ('even', 'RB')
# ('with', 'IN')
# ('the', 'DT')
# ('case', 'NN')
# ('on', 'IN')
# ('it', 'PRP')
# ('.', '.')
# ('Comfortable', 'JJ')
# ('enough', 'RB')
# ('to', 'TO')
# ('wear', 'VB')
# ('and', 'CC')
# ('can', 'MD')
# ('still', 'RB')
# ('use', 'VB')
# ('the', 'DT')
# ('screen', 'NN')
# ('through', 'IN')
# ('the', 'DT')
# ('plastic', 'NN')
# 'galaxy,s2,case,screen,plastic'

# %% [markdown]
# <h3>NLTK POS tag meanings</h3><br />
# CC coordinating conjunction<br />
# CD cardinal digit<br />
# DT determiner<br />
# EX existential there (like: "there is" ... think of it like "there exists")<br />
# FW foreign word<br />
# IN preposition/subordinating conjunction<br />
# JJ adjective 'big'<br />
# JJR adjective, comparative 'bigger'<br />
# JJS adjective, superlative 'biggest'<br />
# LS list marker 1)<br />
# MD modal could, will<br />
# NN noun, singular 'desk'<br />
# NNS noun plural 'desks'<br />
# NNP proper noun, singular 'Harrison'<br />
# NNPS proper noun, plural 'Americans'<br />
# PDT predeterminer 'all the kids'<br />
# POS possessive ending parent's<br />
# PRP personal pronoun I, he, she<br />
# PRP\$ possessive pronoun my, his, hers<br />
# RB adverb very, silently,<br />
# RBR adverb, comparative better<br />
# RBS adverb, superlative best<br />
# RP particle give up<br />
# TO to go 'to' the store.<br />
# UH interjection errrrrrrrm<br />
# VB verb, base form take<br />
# VBD verb, past tense took<br />
# VBG verb, gerund/present participle taking<br />
# VBN verb, past participle taken<br />
# VBP verb, sing. present, non-3d take<br />
# VBZ verb, 3rd person sing. present takes<br />
# WDT wh-determiner which<br />
# WP wh-pronoun who, what<br />
# WP\$ possessive wh-pronoun whose<br />
# WRB wh-abverb where, when<br />

# %% [markdown]
# <h3>NLTK – Name Entity Recognition</h3><br />
# - NER is the first step towards information extraction from unstructured text.
# - Extracting what is a real world entity from the text (Person, Organization, Event).

# %%
from nltk import word_tokenize, pos_tag, ne_chunk
sentence = "Amin and Fred are working for Macquarie university since 2017."
print(ne_chunk(pos_tag(word_tokenize(sentence))))

print(ne_chunk(pos_tag(word_tokenize("Australia"))))
# Out:
# (S
#   (PERSON Amin/NNP)
#   and/CC
#   (GPE Fred/NNP)
#   are/VBP
#   working/VBG
#   for/IN
#   (ORGANIZATION Macquarie/NNP)
#   university/NN
#   since/IN
#   2017/CD
#   ./.)
# (S (GPE Australia/NNP))

# %% [markdown]
# <h2>Practical</h2><br /><hr />
# <h3>Database:</h3><br />
# 1- Download the Amazon JSON file (<a href="https://drive.google.com/file/d/1VKFoztinuLthitrSxPva8TcKPghcPR0B/view?usp=sharing">Amazon.zip</a>) and extract it. It has 194,439 reviews for different cell phones.<br /><br />
#
# 2- Import it into MongoDB, use “amazon” for your database name and “reviews” for you collection name. Please note that this file is <b>NOT</b> a JSON Array so the jsonArray option in $mongoimport$ command is not necessary.<br /><br />
#
# 3- With the right query and from the Mongo command line count the number of imported reviews.<br /><br />
#
# <hr />
# <h3>Application:</h3><br /><br />
# 1- Develop a Python application that connects to the amazon database and query all the reviews consist of “Nokia” in their “reviewText” field.<br /><br />
#
# 2- Use NLTK to identify all the keywords in the “reviewText” field (verbs, Adjectives and Nouns).<br /><br />
#
#
# 3- Put the keywords in a comma-separated string and add that to its relevant field in the database. Use the format below:
# “reviewKeywords”:”searching,battery,baby,monitor,Levana,BABYVIEW20,found,uses,Nokia,battery,was,nervous”<br /><br />
#
# 4- (Optional) Use the Name Entity Recognition in NLTK to recognise name entities in the extracted keywords. Add another record called Entities consists of these objects.<br /><br />

# %%
from nltk import word_tokenize, pos_tag
from pymongo import MongoClient
import re


def textAnalysis(text):
    tokens = word_tokenize(text=text)
    tagged = pos_tag(tokens)
    csv = ""
    for e in tagged:
        if (e[1] == 'NN' or  # Noun, Singular
                e[1] == 'NNP' or  # Propoer Noun
                e[1] == 'NNS' or  # Noun Plural
                e[1] == 'NNPS' or  # Proper Noun, Plural
                e[1] == 'VB' or  # Verb, base
                e[1] == 'VBD' or  # Verb, past tense
                e[1] == 'VBG' or  # Verb, Gerund/present participle
                e[1] == 'VBN' or  # Verb, past participle
                e[1] == 'VBZ' or  # Verb,3rd person
                e[1] == 'JJR' or  # Adjective Comparative
                e[1] == 'JJS' or  # Adjective superlative
                e[1] == 'JJ' or  # Adjective
                e[1] == 'RB' or  # Adverbs
                e[1] == 'RBR' or
                e[1] == 'RBS'):
            if (csv == ""):
                csv = e[0]
            else:
                csv = csv + "," + e[0]
    return csv


db = ""
try:
    connection = MongoClient("mongodb://localhost:27017")  # Connection String
    db = connection.amazon
except:
    print("Something went wrong!")

regx = re.compile("Nokia", re.IGNORECASE)
cursor = db.reviews.find({"reviewText": regx}, {"reviewText": 1})

count = 0
print(cursor[0]['reviewText'])
for e in cursor:
    count += 1
    csv = textAnalysis(e['reviewText']) # Analyzing the review text

    db.reviews.update({"_id": e['_id']}, {"$set": {"keywords": csv}}) # This line updates the database
    
    print(csv)
    print()
    
print(count)
# Out:
# I got a pair of Plantronics-branded headsets in Verizon OEM packaging (plastic bag), each coming with a "universal" adapter (micro-USB male to 2.5mm female). The price was substantially the same (per unit). But there is a small issue--there are two sets of pictures on this product that represent two different units. The two on the right, with the plastic bag that is clearly labeled MX150xxxx are identical to what I have. Note the obvious button showing through the plastic (this one mutes, turns off the call or voice-dials on my Blackberry, but it may do other things on other models). However, the other photos show the same headset, but without the control button--not a different button, but nothing at all! This made me wonder what is being sold as MX150. The other issue is color. It's not clear if you get the black or a gray one or even if there is a choice. From the photo, one would assume that this dealer supply the gray ones, but I am not so sure. This is not exactly an item one buys for style points (it's compact, but looks bulky on the face), so it's a minor point, but it would be good to have some clarity.But, as far as the product itself goes, it's perfectly functional for the purpose--cheap branded headset (for me, specifically to complement a BT set, which this one replaces when charge runs out). I've had a number of cheap or free headsets (often even enclosed with a phone) and virtually all of them have awful raspy and tinny sound. That's not what I want in a headset, even for $3. But I needed an emergency headset and this one fit the bill. The sound quality is far superior to no-name headsets--on both ends. It's better than an average Sony/Ericsson handset--I always add a headset to those when using them since Sony deliberately puts crappy speakers into Ericsson phones to make you buy their headsets. When traveling through NY or DE or any other state that requires no-hands on the phone, it is essential to be quickly disconnect and replace a discharged BT headset. I have no qualms about using this one.UPDATE (9 months later): I got another of these sets for a friend but, although it fit, the phone rejected it as not compatible. It was a cheap ATT/Nokia handset to replace a lost phone so I am not surprised about compatibility issues. But that also meant that I got an extra set. About a month ago, one of the sets died when the phone got yanked too hard (probably a loose contact). At less than $2 each, I had no problem tossing it and pulling out the next one (and I still have two more left, having spent a total of $6, including shipping). So, aside from Nokia compatibility, still no complaints.
# got,pair,Plantronics-branded,headsets,Verizon,OEM,packaging,plastic,bag,coming,universal,adapter,micro-USB,male,female,price,was,substantially,same,unit,is,small,issue,sets,pictures,product,different,units,right,plastic,bag,is,clearly,labeled,MX150xxxx,identical,Note,obvious,button,showing,plastic,mutes,turns,call,voice-dials,Blackberry,do,other,things,other,models,However,other,photos,same,headset,control,button,not,different,button,nothing,made,wonder,is,being,sold,MX150,other,issue,is,color,'s,not,clear,black,gray,even,is,choice,photo,assume,dealer,supply,gray,ones,not,so,sure,is,not,exactly,item,buys,style,points,'s,compact,looks,bulky,face,'s,minor,point,be,good,have,clarity.But,as,far,product,goes,'s,perfectly,functional,purpose,cheap,branded,headset,specifically,complement,BT,set,one,replaces,charge,runs,had,number,cheap,free,headsets,often,even,enclosed,phone,virtually,awful,raspy,tinny,sound,'s,not,headset,even,needed,emergency,headset,bill,sound,quality,is,far,superior,no-name,headsets,ends,'s,better,average,Sony/Ericsson,handset,always,headset,using,Sony,deliberately,puts,crappy,speakers,Ericsson,phones,make,buy,headsets,traveling,NY,DE,other,state,requires,no-hands,phone,is,essential,be,quickly,disconnect,replace,discharged,BT,headset,qualms,using,one.UPDATE,months,later,got,sets,friend,fit,phone,rejected,not,compatible,was,cheap,ATT/Nokia,handset,replace,lost,phone,so,not,surprised,compatibility,issues,also,meant,got,extra,set,month,ago,sets,died,phone,got,yanked,too,hard,probably,loose,contact,less,had,problem,tossing,pulling,next,one,still,more,left,having,spent,total,including,shipping,So,aside,Nokia,compatibility,still,complaints
#
# ..and,Europe,phones,networks,much,better,States,say,Samsung,currently,best,software,used,be,huge,Nokia,fan,Amazingly,light,very,intuitive,great,audio,just,looks,great,reservations,whatsoever
#
# phone,was,purchased,T-Mobile,plan,replace,Nokia,phone,AT,amp,T.,changed,phones,service,old,phone,not,get,reception,buildings,chose,V300,due,external,antennae,had,phone,weeks,now,been,very,pleased,reception,is,bit,tinny,sometimes,overall,not,had,problems,dropped,calls.I,text,message,quite,frequently,phone,offers,choices,writing,text,first,is,intuitive,text,entry,method,phone,guesses,words,trying,type,displays,screen,choose,method,is,supposed,save,time,not,yet,gotten,hang,second,method,is,tried,true,press,button,letter,method,only,problem,phone,is,buttons,not,same,shape,spaced,makes,text,messaging,bit,trickier,first,numbers,letters,written,buttons,very,light,often,shift,angle,phone,order,just,read,buttons,light,text,also,be,issue,someone,vision,problems.Overall,recommend,phone,only,reason,gave,stars,instead,is,Motorola,needs,darken,text,buttons,users,text,message,vision,problems
#
# Positives,Bluetooth,IR,port,VGA,Camera,multiple,e-mail,accounts,speaker,phone,more,programs,becoming,available,Symbian,O/S,wireless,headset,make,phone,serve,wireless,modem.Negatives,phone,too,big,voice,recognition,worthless,low,volume,ear,piece,IR,port,weak,so,TV,remote,control,programs,n't,work,well,slow,menu,response,Get,Opera,browser,phone,does,not,come,WAP,browser,only,frustrate,Opera,has,problems,phone,works,most,time,T-Mobile,programmed,backlight,display,turn,few,seconds,Nokia,made,adjustable,T-Mobile,n't,fix
#
# OPERATION,'s,BMW,I-Drive,does,'s,job,has,most,unintuitive,overly-layered,interface,example,memory,card,is,battery,phone,be,shut,taken,apart,change,memory,card,turning,phone,back,takes,little,while,is,representative,entire,phone,operation,Not,impatient.If,never,used,advanced,mobile,phone,assume,is,par,course,simply,is,n't,Even,instruction,booklet,is,order.APPLICATIONS,has,lots,applications,very,well,eventually,finally,matter,accustomed,phone,too,much,time,is,required,get,open,close,applications,other,hand,leave,many,applications,once,hide,return,just,left,similar,Mac,Me,likes.The,has,more,ameneties,most,World,phone,Camera,VGA/zoom/night,mode/timer,Video,w/,audio,zoom,Speaker,good,sound,Bluetooth,infrared,Modem,computers,electronic,wallet,Internet,access,Calendar,calculator,converter,more.The,phone,does,not,have,Mp3-player,FM,radio,color,screen,megapixel,camera,quad,band,PDA,photo,editor,not,sure,phone,w/,above,features,exists,just,yet,not,sure,want,spend,THAT,much,time,w/,device,anyhow.DEPENDABILITY,seen,glitches,had,problems,phone.STYLING/ERGONOMICS,keys,small,generally,does,n't,bother,spaced,employ,little,'Braille,keys,other,so,careful,attn,be,paid,dialing.As,appearance,'s,subjective,Few,look,phone,know,'s,'s,not,as,stylized,Sony,Samsung,Less,Benz/obvious,more,has,chubby,hips,device,is,n't,really,so,big,Solid,squeak-free,large,screen.MEMORY/STORAGE,Seemingly,boundless,First,all,phone,houses,great,deal,memory,multiple,videos,sound,clips,photos,texts,Secondly,info,be,sent,computer,w/o,hassle,USB,wires,Still,not,sure,phone,memory,sent,computer,is,memory,card,w/a,good,deal,storage,as,well,is,small,deal,still,whining,storage,deleting,games,free-up,still,more,memory.RECEPTION,really,depends,locale,carrier,T-Mobile,is,true,'world,phone,has,mhz,operate,globe,including,New,Zealand,Australia,available,Cingular,replaces,w/,latter,provide,better,coverage,more,remote,areas,States,still,operates,many,countries,excluding,New,Zealand,Australia,provide,similar,service,more,developed,areas,States,not,as,well,more,remote,areas,uses,operates,more,countries,battery,life,is,less,stellar,charges,quickness,Remember,phone,uses,operating,system,Symbian,'s,feature-rich,w/,colors,films,second,video,crying,loud,battery,life,n't,be,very,long,let,not,be,greedy.GAMES,Java,n't,use,so,addtl,space,humble,opinion,games,w/,phones,belong,hands,teenagers.IMP,important,pieces,advice,Visit,Nokia,site,number,downloads,needed/available,phone,be,texted,cost,downloads,basic,advanced,operations.The,second,piece,advice,Be,prepared,spend,lot,time,w/,phone,be,able,pick,things,rush,common,sense,many,times,end,frustrated,Sony,Ericcson,be,phone,good,luck,finding,w/,features,competitive,price,Keep,mind,nearly,screen,number,'along,side,'beneath,choices,phone,memory,memory,card,sim,card.Despite,critical,start,phone,deserves,stars,accomplishes,sets,do,is,pretty,lofty,does,more,most,does,well,is,dependable,'s,high-line,Audi,Cadillac,suspension,reasonable,price.When,expandability,downloads,computer,numerous,features,transmission,programs,multiple,storage,devices,dependability,is,phone,is,n't,easy,out-grow.I,suggest,phone,simple-minded,simply,n't,need,so,many,features
#
# been,waiting,finish,year,contract,get,phone,i,did,find,bad,reviews,let,tell,folks,awesome,phone,Palmone,T3,i,really,having,good,time,now,neeed,try,sync,option,soon,i,much,satisfied,giving,stars,keys,placed,little,odd,thanks
# been,months,now,held,Nokia,purchased,phone,knowing,was,slightly,old,compared,newer,models,Nokia,phones,available,thought,was,kind,steeply,priced,time,add,dismay/delight,readers,phone,is,simply,most,groundbreaking,phone,mankind,has,ever,held,has,raised,bar,owing,number,features,offers,absolute,ease,use,delight.Now,techy,getting,technical,things,so,brief,few,features,liked,phone-1.The,Phone,has,best,keypad,Nokia,phone,has,offer,dad,has,Nokia,has,Nokia,had,Nokia,keypad,cell,phone,is,most,important,thing,Im,constantly,sending,messages,calling,people,fiddling,around,phone,Believe,used,fingered,Nokia,phones,has,best,keypad2,looks,absolutely,nonsensical,being,tad,too,bulky,looking,admit,not,best,looking,phone,ever,then,has,look,static,absolute,conviction,looks,everything,phone,be3,Nokia,has,brilliant,Java,interface,'s,whole,lot,things,do,phone,reading,book,playing,various,Java,games,having,variety,software,installed,Phone,offers,Mb,MMC,card,is,certainly,most,exciting,feature,upgraded,mine,MB,MMC,Card,store,unlimited,number,messages,thousand,pictures,videos,Capacity,is,not,problem,here.4,Build,is,just,right,phone,is,sturdy,dropped,dozen,times,recolletion,still,works,as,good,ever,tough,one,na,drive,car,is,n't,most,rugged,phone,ever,then,not,gon,play,aeroplane,you.5.The,Camera,installed,phone,is,awesome,pictures,JPG,format,phone,has,bluetooth,device,extremely,easy,transfer,pics,pc,forth,display,brightness,phone,is,quite,extraordinary,use,colors,ensures,get,share,animations,icons,phoneBesides,above,mentioned,Merits,phone,has,decent,ear,volume,loudspeaker,functionality,has,great,upgradibility,play,MP3,files,phone,simply,downloading,softwares,freely,available,net,Now,is,neat,log,functions,incoming,outgoing,calls,most,easy,ways.The,handsfree,provided,phone,is,useful,phone,driving,n't,do,'s,not,worth,life.Anyhow,demerits,phone,phone,has,slow,processor,ear,volume,is,lower,then,has,best,ear,volume,most,Nokia,variants.The,battery,life,phone,is,most,days,least,day,excessive,use,Video,recording,is,limited,just,seconds,upgrade,then,'s,certain,level,trouble,involved.Overall,ever,upgrade,phone,purchased,phone,thought,myself,had,purchased,most,popular,phone,around,thought,did,n't,please,case,putting,common,is,city,be,anymore,satisfied,makes,great,phone.Did,note,feature,send,notes,Bluetooth,gee,anyways,ENJOY,WHAT,WORKS
#
# received,little,gem,Christmas,now,speak,phone,BT,enabled,unit,is,perfect,gift,anyone,cell,phone.No,more,complicated,setups,As,soon,turned,Nokia,found,recognized,associated,was,speaking,it.The,battery,life,is,great,clarity,is,also,dead,on.Once,product,too,never,go,back,speaking,phone,old,fashioned,way
#
# Pros,function,design,headset,first,rate,Right,box,was,easy,pair,Motorola,v505,phone.It,is,small,unobtrusiveThe,battery,life,is,really,good,standby,mode,lasts,several,hours,talking,does,issue,warning,tones,battery,runs,low,phone,issues,message,saying,headset,signal,weak,switch,handset,combo,belt,clip/charger,is,really,cool,idea,have,been,EVEN,COOLER,Jabra,had,made,compatible,nokia,Moto,Ericsson,phone,chargers,Now,yet,ANOTHER,power,supply,drag,trips,.Reception,is,very,good,as,long,line,sight,is,unobstructed,anything,full,water,pump,gas,car,phone,passenger,seat,wander,hotel,suite,waving,arms,wildly,phone,sits,charging,stand,desk,is,body,way,aquarium,then,signal,drops,attenuates,dramatically,fact,is,marked,difference,putting,phone,opposite,side,body,earpiece,carrying,phone,pocket,opposite,side,signal,degrades,noticeably.The,Cons,been,unsuccessful,getting,pair,laptop,PDA,however,HP,iPaq,.If,bluetooth,PDA,use,BT,Activesync,PC,interfere,headset,is,connected,Activesync,perspective,hear,constant,crackling,noise,sounds,other,person,is,popping,popcorn,took,while,figure,n't,have,turn,BT,radio,laptop,PDA,just,disconnect,BT,session,temporarily,talking,is,hassle,not,killer,reasons,instead,stars,biggest,problem,unit,is,does,not,fit,ears,feeling,very,insecure,hanging,design,always,feels,is,flopping,around,too,far,side,unit,actually,fall,ear,is,way,tighten,fit,unit,already,tried,different,earpieces,positions,earpieces,does,n't,help,is,reason,probably,replace,unit,shame,is,such,nice,unit,floppiness,ears,is,unacceptable.BTW,not,midget,weigh,lbs,fairly,narrow,face,bigger,issue,is,small,earlobes,small,earlobes,rather,pendulous,ones,want,test,fit,unit,store,buying,here,had
#
# phone,is,flashy,feels,good,hand,not,hold,connection,bluetooth,devices,headset,handheld,desktop,computer,old,Siemens,s56,other,hand,worked,beautifully,above.If,web,find,many,websites,people,complaining,lack,drivers,phone,cavelike,silence,Nokia,asked,help.If,needs,limited,making,phonecalls,taking,snapshots,phone,probably,satisfy,Bluetooth,stay,away
#
# owned,versions,unit,Nokia,apparently,requires,specific,type,compared,other,BT,phones,second,one,currently,is,Motorola,V600.This,comparison,cover,Jabra,units,compare,Nokia,HDW-2,Blutooth,adapter,as,well,Motorola,HS-820,bluetooth,adapters.The,jabra,unit,boasts,much,better,design,other,sit,ear,feel,extremely,awkward,jabra,design,provides,much,better,more,comfortable,fit,even,glasses,other,has,flimsy,ear,plastic,pieces,very,place.I,felt,unit,be,relatively,easier,use,compared,other,had,NO,problems,teaming,units,did,have,jump,few,hoops,team,V600.THE,most,important,reason,wanted,BT,adapter,first,place,was,due,fact,i,phone,signal,liviing,room,is,signal,desk,basement,is,directly,living,room,reception,was,same,not,use-able,also,noticed,went,corner,lose,signal,true,units.All,rate,follows,scale,Quality,jabra-4,Nokia-3,Motorola-2.5Design,Jabra-5,Nokia-1,Motorola-1usabaility,range,Jabra-3,Nokia-3,Motorola-3usability,ease,use,Jabra-4,Nokia-3,Motorola-3Overall,Jabra-4,Nokia-2,Motorola-2One,thing,i,did,not,get,test,was,battery,life,Jabra,did,provide,good,half,days,battery,time,single,charge,i,did,not,get,test,battery,life,Nokia,Motorola,units
#
# Paired,nokia,Awesome,headset,battery,life,is,pretty,long,feels,really,light,ear,sound,is,excellent.Some,people,be,going,deaf,something,thing,get,loud,never,volume,max,thing,feels,heavy,ear,have,ears,size,nickels,using,same,ear,i,n't,know.Whenever,sometimes,unit,rings,makes,twitch,not,expecting,ring,blasting,thru,ear.I,hate,-wind,noise,n't,carry,conversation,driving,windows,walking,wind,blowing,face.-voice,dialing,not,work.-it,makes,phone,hang,reset,be,phone,problem,general.-30,feet,more,best
#
# keyboard,fills,left,pocket,Ultra,mobile,PC,phone,fills,right,pocket,keyboard,allows,type,normal,speed,device,keep,pocket,was,astonished,see,have,even,worked,text,messaging,older,phone,Nokia,N-Gage,HTC,phone,phone,supports,keyboard,even,PDA,highly,product,is,costly,Pair,anything,run,TextMaker,Office,WindowsMobile,meeting,powerhouse,pocket,tackle,best,college,note,taking,much,more,mobile,manner,laptop,n't,need,take,bag,plug,otherwise,waste,time,also,pairing,mouse,same,company,same,purpose
#
# Use,Nokia,N95-3,works,very,well.A,bit,bulky,not,really,pocketable,fits,bags,easy,transport.Great,using,airplanes,is,small,not,take,entire,table.Some,keys,very,touchy,noticed,E,button,press,twice.All,very,nice,product
#
# had,SKII,fo,little,month,now,find,good,fit,needs,business,user,not,Snoop,Dog,groupie,is,VERY,cool,device.Coverage,area,Austin,TX,is,good,not,yet,traveled,away,IH-35,corridor,had,good,voice,data,coverage,way,TX/OK,stateline,far,north,went,eat,data,is,screaming,deal,n't,find,web,surfing,useful,speed,is,dial-up,connection,email,is,superior,Blackberry,used,number,years,ago,interface,phone,email,address,book,is,great,Far,better,Nokia,phone,ever,used,intellisync,software,allows,create,use,separate,address,book,Outlook,then,sync,SKII,button,push,Very,simple,means,have,abreviated,address,book,concerned,having,infor,resident,TMO/Danger,servers,reviewier,be,better,info,is,NOT,resident,'s,concern,server.Drawbacks,bluetooth,resident,memory,email,pictures,removable,memory,stick,easy,way,create,use,own,ringtones.Great,things,great,keyboard,nicer/bigger,Crackberry,intuitive,interface/software,screen,size/clarity,Camera,nice,feature,easy,email,pics,anywhere,very,cool,functional,device,phone,email,web,other,stuff,OK,TMO,data,network,have,get,faster,more,WAP,coded,websites,content,is,relevent,be,big,reason,buy/use,device.I,purchased,Danger,website,total,cost,instant,discount,rebates,year,contract,TMO,book,Paying,regional,anytime,minuets,eat,data,email,text,messaging,EVERYTHING,DATA,included,.I,recommend,anyone,really,needs,email,occaisional,web,service,addition,phone,service,Not,smallest/best,coolest,phone,best,convergent,communication,device,market,right,now,IMHO
#
# Got,headset,replace,Jabra,was,incompatable,Nokia,Fit,comfort,is,extremely,subjective,found,Jabra,be,far,more,comfortable,actually,forget,was,wearing,said,unit,is,not,uncomfortable,couple,hours,just,not,nearly,comfortable,securely,fitting.Very,few,complaints,as,far,performance,was,easy,pair,phone,wife,Motorola,V3,even,laptop,Sound,quality,is,clear,parties,recipients,occasionally,complained,pinging,noise,Jabra,noise,reduction,actually,works,eliminate,wind,noise,Battery,life,is,excellent,single,function,be,little,aggrevating,especially,trying,turn,hold,long,time,only,weird,very,rare,quirk,is,occassionally,calls,be,interrupted,strange,sound,sounds,someone,dropping,manhole,cover,spins,pavement,very,strange,very,annoying,fortunately,very,rare.Overall,performance,is,top,notch,comfort,is,acceptable,value,is,difficult,beat
#
# were,exactly,mother,needed,old,Nokia,goes,quickly,got
#
# owned,Palm,type,years,had,cell,phone,slightly,less,time,always,resisted,buying,combined,device,thought,n't,ready,yet,came,time,replace,PDA,decided,Treo,be,ready,had,concerns,size,screen,integrating,PDA,cell,phone,functions,Overall,most,nervousness,was,groundless,pleased,phone,so,far.Good,points,Works,well,phone,Better,signal,Nokia,phone,replacesScreen,is,very,readable,even,is,smaller,traditional,PDAPalm,functionality,is,fine,interface,has,been,redesigned,bit,seldom,stylus,Most,entries,done,rocker,switch,bottom,center,screen,keypad,truly,do,many,functions,one-handed,managed,do,losing,feel,Palm,n't,having,re-learn,zero.The,memory,is,non-volatile,English,means,batteries,dead,n't,lose,data,till,Palm.Bad,points,slight,delay,dialing,number,Palm,contacts,list,right,'s,not,really,problem,is,annoying,couple,second,delay.If,books,Palms,not,sure,screen,do,prolonged,reading.Battery,life,is,fair,able,get,days,medium,use,bit,life,left,battery,Not,days,monochrome,Palms,go,week,recharges,'s,only,so-so,web,browser.The,price,is,hideously,high.Keyboard,is,cramped,as,good,expect,such,small,device,is,definitely,useable,instinct,was,use,right,thumb,only,now,people,hands,only,be,seen,Treo,not,believe,upgrade,be,currently,waiting,make,jump,combined,PDA/phone,is,good,point,do
#
# NOT,get,charge,Did,not,sent,back,cost,more,ship,back,help,got,did,order,Nokia,BL-5C,works,great
#
# was,no,longer,obtain,good,quality,BL-5C,finally,gave,Nokia,phone.I,last,battery,tried,was,actually,had,worse,performance,battery,had,used,year,was,trying,replace.These,be,phonies,China,just,so,old,chemically,inert,afraid,n't,recommend
# issues,battery,order,OEM,Nokia,BL-5C,battery,advertised,Nothing,exciting,performance,is,be,new,battery,Price,was,excellent,compared,retail,very,satisfied,purchase
#
# searching,searching,battery,baby,monitor,Levana,BABYVIEW20,found,uses,Nokia,battery,was,too,nervous,buy,type,product,seller,other,Amazon,did,just,works,fits,perfectly
#
# recently,purchased,batteries,four-year-old,Nokia,cell,phones,Based,month,trial,batteries,hold,charge,reasonable,amount,time,much,better,old,batteries,be,good,choice,especially,money
#
# does,n't,have,range,Nokia,headset,i,tried,is,vastly,more,comfortable,used,Samsung,t809,had,issues,couple,days,review,Range,was,feet,supposed,have,signal,fading,was,rapid,Very,light,easy,use,fortunately,mid,signal,tones
#
# bought,H500,few,years,ago,first,came,was,plagued,low,volume,poor,connection,using,nokia,bluetooth,last,year,got,again,cell,phone,laws,California,July,headset,is,plenty,loud,Sony,Ericsson,T650i,n't,had,drop,bluetooth,connection,yet,volume,sits,little,half,hear,perfectly,car,Battery,life,rocks,voice,clarity,is,lot,better,remembered,first,H500.4,stars,ear,clip,is,flimsy,does,n't,allow,H500,sit,tightly,ear,So,planning,using,while,running,intense,walk,n't,count,it.Definitely,recommend,great,device,Ca,n't,go,wrong,price
#
# Right,say,comes,cell,service,phones,inherent,contracts,more,ways,buyer,beware,research,ad,nauseum,getting,new,contract,bed,new,cell,provider,been,Nextel,subscriber,years,i90,i730,lovely,phones,service,very,professional,Nextel,coverage,features,expected,said,researched,death,bought,phones,service,Got,phones,Amazon.I,too,was,taken,looks,RAZR,so,was,wife,saw,was,as,good,looked,was,worth,worth,switching,carriers,Nextel,was,n't,making,easy,stay,got,bed,Sprint,had,Sprint,years,still,have,nightmares,customer,service,price,upgrade,phone,Nextel,was,*unacceptable*,point,view,Everyone,knows,cheaper,phone,new,contact,got,RAZR,local,retailer,sorry,Amazon,rebates,Cingular,n't,effort,paid,best,price,*anywhere,*,got,family,plan,is,par,Verizon,saves,bunch,money,Nextel,A,*bunch*,money,words,rollover,spent,just,hour,charging,phone,reading,manual,configuring,phone,function,as,well,not,better,i730,is,*great*,phone,noticed,similarities,function,detail,quality,Sony,Motorola,Nokia,phones,friends,mine,manual,is,something,many,people,avoid.For,anyone,complaining,phone/,address,book,shame,was,worried,address,book,based,reviews,minutes,manual,using,phone,got,RAZR,do,*everything*,nifty,i730,do,then,so,many,ways,configure,address,book,'s,silly,assign,create,categories,numbers,addresses,even,phone,only,display,certain,categories,only,flip,thru,numbers,flip,thru.As,complaints,battery,life,RAZR,has,six-plus,hour,talk,time,better,phones,market,today,say,cos,researched,phones,market,plug,phone,sleep,night,*guarantee*,be,fully,charged,morning.Fragile,phone,clumsy,beaten,lots,phones,years,expect,just,anything,side,brick,break,Half,i730,is,made,same,material,RAZR,is,has,lousier,belt,clip,boot,has,allowed,i730,fall,ground,way,too,many,times,happy,material,'s,expected,durability,Stop,throwing,delicate,*expensive,*,micro-electronic,device,'s,made,teflon,*Be,careful,*I,not,camera-phone,bandwagon,primarily,is,required,merge,technologies,is,'s,nature,usually,expensive,difficult,good,example,is,ROKR,so-called,iTunes,phone,iPod,phone,had,come,close,actually,blending,best,wireless,world,abilities,iTunes,iPod,have,bought,came,far,short,doing,cos,blending,ideas,is,n't,easiest,thing,pull,well,RAZR,is,not,expensive,has,great,camera,large,memory,stick,capture,full-motion,video,zip,dorm,room,buddies,blink,eye,'s,expensive,'s,*slick*,looking,phone,makes,other,phones,shelf,self-conscious,Most,professional,reviews,phone,gave,low,marks,camera,abilities,so,n't,be,surprised,Want,good,camera,phone,Cingular,Sony,s710,got,great,reveiws,good,luck,getting,less,twice,RAZR,costs,'s,difference.Last,thing,got,phone,knowing,days,send,whole,thing,back,'s,not,working,'s,little,consumer-friendly,cushion,give,time,fully,evaulate,phone,Still,did,research,there,n't,be,too,many,surprises,got,phone.Hope,helps
#
# bought,becasue,was,very,happy,see,phone,metal,case,again,used,just,use,nokia,phones,back,day,break,least,once,month,Bought,Moto,v60,was,really,blown,away,best,phone,ever,had,Then,upgraded,color,phones,tried,other,Motos,Really,big,disapointment,Moto,phones,made,so,cheap,fall,apart,just,nokia,came,jumped,Finally,Moto,was,going,back,quality,phones.PROS,-Some,sturdy,case,metal,parts,solid,marks,yet,month,.-The,battery,life,is,little,tiny,bit,higher,then,average,phone,charge,night,has,least,life,left,about,hours,day.-Camera,is,ok,not,best,far,not,worst.-Slim,form,factor,yes,wider,then,normal,flip,is,good,size,Other,phones,always,seemed,skinny,me.CONS,is,metal,bottom,is,plastic,seems,be,cheap,plastic,creaks,is,antenna,is,has,SAR,rating,.80,ear,then,much,jaw,is,getting,jaw,get,cancer,then,brain,right,-The,vol,is,almost,joke,is,so,low,highest,normal,phone,is,middle,setting,used,have,turn,people,cell,now,struggling,hear,sometimes.-The,keypad,looks,nice,pain,butt,donut,thing,middle,is,already,scracthed,finger,nail,rest,keypad,is,protected,seems,has,marks.-A,pain,clean,keypad,is,shiny,gets,rubber,lining,keys,part,ever,using,gets,looking,even,book,Good,god,man,fact,used,phone,book,really,shows,n't,put,lot,effort,phone,was,total,mess,up,way,is,true,shame.-Good,luck,support,warranty,Moto,Past,experiences,was,very,poor,phone,get,fixed,month,later,back,did,n't,even,read,problem,was,fix,send,still,broken.The,reason,phones,cheap,plastic,opinion,is,do,months,phone,looks,dropped,stairs,few,dozen,times,Strong,durable,plastic,is,used,time,crying,loud,Glad,uses,time,more,then,happy,pay,dollars,quality,money,same,phone,is,not,even,close,meeting,expectations,thought,get,dollar,basic,cell,phone,high,standards,top,dollar,best,Moto,be,seeing,is,offering,good,rebates,now,something,Amazon,now,Well,other,reviewer,Verizon,CDMA,phone,is,only,GSM,ever,make,CDMA,version,course,real,clue,Call,Motorola.Also,sorry,spelling,mistakes,take,much,time,go,back,review,wrote,not,getting,paid,n't,waste,time,Good,luck,be,very,happy,phone
#
# had,phone,while,now,here,'s,User,Interface,has,had,bad,rap,people,'s,not,as,intuitive,say,Nokia,interface,does,have,pros,customize,button,including,arrows,left,right,soft,keys,left,soft,key,programmed,go,Shortcuts,function,right,there,course,while,use,get,used,interface.The,volume,phone,is,decent,problems,hearing,other,people,problems,hearing,Speakerphone,works,great,too,boyfriend,says,longers,feels,'s,talking,someone,tunnel,speakerphone,calls,only,volume,problem,see,is,highest,volume,is,still,slightly,hard,hear,phone,ring,other,thing,phone,has,way,cool,ringtones.The,address,book,issue,is,SIM,card,store,addresses,then,not,be,able,have,multiple,entries,person,phone,memory,store,numbers,have,many,many,numbers,stored,entry,numbers,stored,Powerbook,address,book,not,too,worried,having,SIM,card,MAC,iSync,works,wonders,syncing,numbers/calendars,RAZR,'S,cool,screen,is,very,large,clear,problems,seeing,dark,even,bright,light,had,problems,reception,Cingular,so,far,fact,stronger,signal,most,places,previous,phone,Nokia,Overall,very,pleased,design,functions,asthetics,phone
#
# Sexy,form,CHECK,Innovative,construction,CHECK,Exclusive,price,tag,CHECK,sea,flip,phones,candy,bar,phones,look,alike,RAZR,V3,is,Ferrari,mobile,phones,stands,such,looking,feature,rich,phone,then,V3,is,not,V600,provide,same,features,far,less,high-quality,constructed,phone,screams,look,sexy,b*tch,then,V3,is,alley.Actually,better,analogy,be,Acura,NSX,mobile,phones,NSX,V3,is,marketing,tool,Motorola,'s,way,saying,known,inexpensive,phones,build,stylish,well-crafted,high-end,phones,too,Unless,technology,improves,GSM,V3,is,phone,definitely,keep,more,years,styling,design,construction,is,just,that,good,upgraded,trusty,reliable,yet,mediocre,Nokia,TDMA,phone,'s,been,quite,debate,construction,V3,best,explanation,heard,is,bottom,backside,battery,cover,lower,front,is,plastic,antenna,certainly,makes,perfect,sense,metal,frame,IS,antenna,other,areas,cold,touch,weather,areas,usually,room,temperature,Furthermore,be,misrepresentation,Motorola,part,advertise,such,Regardless,phone,seem,flimsy,'s,very,solid,is,comparison,w/,old,Nokia,girlfriend,V551.Mikey,likeys:1-,mini-USB,port,is,great,single-point,access,data,charging,'s,simple,be,mobile,phone,standard,2-,Bluetooth,connectivity,Coming,wired,hands-free,setup,Bluetooth,headset,Jabra,BT250,is,godsend,leave,V3,charging,home,office,still,be,connected,living,room,SIDE,NOTE,stay,away,D-Link,Bluetooth,USB,adapter,PC,connectivity,get,Belkin,F8T001,adapter,read,review,D-Link,details,Quad,band,Doubtful,ever,use,feature/benefit,words,certainly,impress,speakerphone,been,non-believer,mobile,phone,speakerphones,got,admit,V3,speaker,phone,is,bomb,'s,loud,clear,not,loud,enough,car,girlfriend,tells,better,V3,speakerphone,old,Nokia,wired,headset,setup,n't,have,Bluetooth,headset,spoiled,speakerphone.5-,internal,display,Going,V3,Nokia,is,leap,spacial,proportions,couple,weeks,found,be,spoiled,w/,large,internal,display,not,only,V3,has,ATI,IMAGEON,graphics,accelerator,other,phones,excluding,PDA,phones,comparison,regard.Mikey,no-likeys:1-,No,memory,expansion,n't,see,using,internal,memory,SD/MMC,card,expansion,slot,be,nice,Maybe,Motorola,somebody,else,maybe,come,mini-USB,adapter,purpose.2-,Poorly,written,owner,manual,found,owner,manual,is,more,reference,manual,sometimes,leaves,figuring,things,own,does,not,explain,use,many,common,features,owners,especially,ones,new,Motorola,phones,Instead,lists,features,expects,put,together,'s,C++,Reference,vs,Learn,How,Program,C++,Days.,Maybe,Motorola,technical,writers,just,technical,3-,Drops,dings,Ferrari,probably,go,week-long,mourning,first,time,ding,phone,hoping,be,[,good,],cases,available,protect,V3,juggles,w/,keys,pocket,SIDE,NOTE,heard,Cingular,/,Lockline,is,not,insuring,phone,Cingular,sales,guy,was,hesitant,sell,phone,bought,insurance,EDGE,girlfriend,Motorola,v551,has,EDGE,Shame,shame,shame,Motorola,Bad,Motorola,Bad,bad,bad,Alas,'s,akin,buying,Ferrari,Modena,having,cheap,factory,stereo,system,paying,Acura,NSX,'s,only,Internal,display,colors,was,hyped,hear,colors,Motorola,specs,detective,footwork,is,colors,up,colors,MPEG-4,video,playback,Very,very,sneaky,mis-leading,indeed.Wishlist:1-,wished,was,PocketPC,smart,phone,version,phone,PocketPC,+,V3,form,factor,perfection.Regarding,multiple,numbers,name,review,set,phonebook,display,only,primary,numbers,by:1-,setting,primary,number,names,multiple,numbers,n't,have,do,name,only,has,number,2-,set,address,book,view,Primary,Contacts,Phonebook,Menu,Phonebook,Setup,View,3-,voila,only,primary,numbers,displayed.The,way,Motorola,has,implemented,is,not,very,intuitive,Nokia,implementation,refer,owner,manual,dis-like,found,Motorola,implementation,be,little,more,robust.UPDATE,'s,been,nearly,weeks,bought,phone,buyer,remorse
#
# chief,complaint,phone,is,Ringtone,selector,is,accessible,outside,phone,causes,be,changed,simply,handling,fiddling,pocket,been,numerous,times,i,missed,calls,was,inadverdantly,set,silent,just,being,pulled,pocket,rest,complaints,poor,confusing,Motorola,software,menu,structure,phone,does,quite,bit,rarely,i,find,access,features,even,months,ownership,i,owned,several,other,Motorola,phones,often,talking,buried,inscrutable,set,menu,i,trying,do,something,else,activate,find,number,phonebook,software,is,also,slow,unresponsive,compared,Nokia,Samsung,gives,lazy,inexact,feel,pluses,rubberized,finish,is,easy,grip,full,support,bluetooth,sucks,so,much,battery,power,becomes,borderline,useless,nice,large,well,lit,keys,crisp,screen.The,phone,has,overall,feeling,solidity,being,too,heavy,clumsy,feeling,gotten,more,drops,phone,other,i,never,used,cingular,i,n't,know,service,phone,Overall,i,like,phone,i,searching,something,else,frustrations
#
# did,not,work,day,got,them.The,right,earbud,never,had,sound.I,got,replacement,'s,same,situation.I,not,sure,'s,using,Nokia,E71x,n't,work,properly
# bought,members,family,theie,headsets,using,is,little,background,noise,headset,is,n't,bulky,others,hours,talk,time,has,been,connected,Motorola,Nokia,Samsung,cell,phones.I,had,faulty,was,quickly,resolved,Amazon,Other,products,perfectly
#
# was,first,clamshell,phone,aspect,phone,'s,seems,have,worse,reception,previous,phones,Nokia,bar,type,same,coverage,areas,biggest,issue,is,definitely,battery,NOT,heavy,cell,phone,user,so,just,leave,phone,car,gym,bag,not,worry,couple,days,phone,drain,hours,hours,MINIMAL,USAGE,n't,know,drains,so,quickly,seems,be,random,speeds,is,extremely,frustrating,Also,not,thrilled,intuitiveness,lack,thereof,menus,sure,have,become,familiar,time,n't,have,chance,phone,looking,return,mine,ASAP.CONS,POOR,Battery,LifeWorse,reception,previously,owned,phonesNot,comfortable,holdPROS,Looks,goodCompact
#
# owned,Treo,again,model,came,Initially,was,extremely,frustrated,phone,telephone,performance,lack,stability,Frequent,reboots,freezes,dropped,calls,made,difficult,appreciate,phone,ended,getting,rid,relying,separate,palm,cell,phone,time,PalmOne,has,released,firmware,updates,phone,operating,system,made,phone,very,stable,improvements,so,significant,actually,won,back,review,is,GSM,Treo,word,Carriers,only,GSM,abroad,frequently,limits,Cingular,Tmobile,used,found,Cingular,network,coverage,is,more,complete,especially,rural,areas,Tmobile,network,sounds,better,'s,tradeoff,Tmobile,drop,call,more,often,Cingular,say,more,often,coverage,is,about,equal,big,cities,major,highways,International,roaming,is,less,expensive,Tmobile,Cingular,has,few,hurdles,place,prevent,enabling,international,roaming,account,been,less,months,Verizon,Sprint,cellular,technology,is,US-only,therefore,good,using,phone,phone,pros,pocket,address,book,datebook,notes,e-mail,low-res,still,video,camera,very,nice,sms,threads,sms,exchanges,contact,web,browser,mp3,player,QWERTY,keyboard,makes,typing,much,faster,standard,phone,interface,is,unique,need,little,time,get,used,once,be,efficient,quick-dialing,keeping,daily,use,other,phone,Also,phone,is,quad-band,GSM,means,work,very,well,abroad,more,common,tri-band,GSM,phones,n't,perform,as,well,Remember,Treo,Smartphone,Verizon,Sprint,not,work,abroad,screen,Palm,version,is,brilliant,Windows,version,is,not,sharp,limitation,imposed,operating,system,Also,GSM,technology,uses,SIM,cards,means,simply,change,SIM,use,phone,network,phone,number,domestically,abroad,have,phone,locked,carrier,network,contract,commitment,is,complete,'s,something,sort,own,phone,cons,said,pocket,thing,belt,bulge,force,make,alterations,sport,jacket,Also,age,identity,theft,information,security,think,long,hard,about,just,much,information,is,there,Believe,phone,quickly,becomes,place,store,passwords,account,information,customer,information,etc,Consider,feel,restaurant,'s,stolen.Here,lesser,cons,be,worked,beauty,palm,phones,is,so,popular,other,people,had,problem,encounter,written,software,address,/,fix,/,work,issue,example,found,phone,volume,is,not,loud,enough,is,party,volume,software,fix,that,as,well,software,allows,use,phone,Bluetooth,modem,computer,software,is,freeware,is,shareware,is,purchase,key,is,so,many,forums,resources,Internet,search,find,answers,phone,allows,install,uninstall,as,much,ease,home,PC.Thoughts,newer,Treo,phones,now,costs,little,less,Treo,come,is,good,thing,n't,see,having,new,features,upgrade,Other,slightly,redesigned,appearance,interface,higher,resolution,camera,phone,features,basically,identical,Also,Summer,Treo,is,only,available,CDMA,networks,Treo,folks,staggered,release,GSM,CDMA,models,give,carriers,turn,exclusivity.Looking,future,is,speculation,next,generation,Treo,phone,be,GSM,be,thinner,lighter,antenna,be,internal,basically,more,resemble,blackberry,outside,much,sought,features,Treo,users,Maybe,upgrade,then.In,conclusion,only,stars,phone,product,was,n't,ready,market,released,'s,much,better,now,had,initially,released,current,product,have,given,stars,perspective,helps,decision.UPDATE,Jan,Treo750,windows,mobile,has,come,UK,Vodafone,here,USA,Treo680,Palm,OS,has,been,announced,Cingular,forums,internet,people,reported,new,addresses,many,wish-list,items,Treo,faithful,slighly,thinner,modest,few,millimeters,internal,antenna,better,keyboard,volume-too-low,issue,sort,resolved,better,mp3,player,pTunes,instead,Real,more,memory,improved,phone,interface,EDGE,instead,GPRS,double,data,speed,Unfortunately,camera,has,same,resolution,few,millimeters,meant,thinner,battery,owners,poor,battery,life,day,significantly,less,power,users,.As,Thanksgiving,vendor,pre-selling,Treo,was,sold,including,Amazon,tells,things,many,Treo,users,looking,upgrade,immediately,choice,not,necessity,result,market,be,flooded,inexpensive,used,Treo650s,doubt,merchants,inventory,probably,sell,inexpensively,enough,people,been,priced,smartphone,market,get,hands,one.Palm,says,is,targeted,day,person,not,p ...
#
# used,headset,Nokia,PC,works,great,switching,back,forth,easily,telling,PC,phone,connect,Light,crackling,occasion,is,active,area,not,terribly,noticeable,Sound,quality,is,great,indoors,great,thing,is,comfort,wear,day,long,even,'s,not,smallest,lightest,headset
#
# Simply,awesome,best,one,ever,had,sticking,one,motorola,nokia,samsung
#
# Ever,i,bought,headset,become,fan,comfortable,wear,whole,day,even,feeling,anythin,is,voice,is,crystal,clear,very,easy,use,pairs,perfectly,nokia,as,well,Dell,Laptop,i,VOIP,calls,mobile,phone,calls,Also,service,was,great,received,package,right,estimated,date,never,had,followup,anyone,Superb,Product
#
# bought,RAZR,v3,phone,July,go,7-Eleven,Speak,Out,Wireless,prepaid,service,phone,received,Amazon.com,was,made,Hong,Kong,market,came,outlet,plug,adapter,U.S.,customers,AC,adapter,is,universal,voltage,slim,paper,manual,is,English,phone,is,quadband,fully,unlocked,be,used,anywhere,world.I,really,RAZR,phone,'s,very,solid,voice,quality,is,excellent,Speak,Wireless,runs,AT,T,T-Mobile,networks,reception,quality,vary,RAZR,does,excellent,job,pulling,as,much,signal,possible,other,Moto,phones,brightness,screen,be,adjusted,ringer,type,volume,be,easily,changed,metallic,keypad,takes,little,getting,used,is,pretty,comfy,use.The,camera,is,only,VGA,takes,good-quality,pictures,'s,plenty,light,Video,capture,is,jerky,limited,seconds,'s,probably,weakest,feature,Bluetooth,linkup,Sony,Ericsson,works,fine,Battery,life,is,admirable,n't,use,phone,much,maybe,just,minutes,week,recharge,once,days,so.Because,owned,many,Moto,so,RAZR,interface,feels,familiar,understand,confuse,users,new,Moto,scene,Overall,n't,think,'s,harder,use,Sony,Nokia.What,really,impresses,is,build,quality,phone,Nowhere,find,thing,is,made,material,fit,finish,excellent,very,happy,inexpensive,purchase
#
# i,bought,replace,cingular,phone,works,well,package,came,europe,charger,cheap,plug,adapter,had,manuals,everything,seemed,legitimate,box,was,n't,sealed,product,was,manufactured,again,everything,works,nokia,UI,battery,time,is,okay,reception,seems,fine,n't,been,able,find,driver,vista,yet,so,n't,been,able,charge,usb.i,buy,unlocked,phone,again
# updated,Good,battery,life+,Very,comfortable,choice,ear,bud,tips,extras,Easy,use+,Minimal,bling,appeal,blue,light,is,not,obtrusive,First,unit,failed,charger,headset,buggy,only,weeks,use-,Jabra,Support,is,lackluster-,Ugly,shiny,mic,piece,photo,Amazon,is,not,accurate,see,customer,images,weeks,use,stopped,charging,AC,adapter,dropped,audio,connections,dialing,minutes,conversation,Replacement,unit,has,also,exhibited,less,Contacted,Jabra,charging,issue,required,headset,RMA,THEN,b,send,new,less,month,use,found,way,get,replacement,boomerang,purchase,local,chain,'tronics,plus,side,lasts,standby,few,days,vice,few,hours,Sony,BT,headset,does,fits,ear,comfortably,ear,very,easily,loop,is,soft,rubber,sharp,rigid,plastic,is,clamping,outer,ear,sound,is,not,quite,loud,enough,volume,controls,easy,find,touch,in-ear,speaker,only,blast,so,much,earbud,be,gently,pressed,form,seal,is,easier,hear,way,Sound,is,so-so,callers,told,n't,hear,ambient,sound,music,wind,cars,nearby,better,average,is,second,Jabra,product,'s,crapped,so,be,wary,always,owning,wired,headset,backup,particularly,business,important,personal,use,JULY,UPDATE,**I,now,used,years,give,much,better,review,unit,has,held,well,tip,broke,had,be,glued,back,still,holds,several,hours,charge,old,Sony,headset,now,lasts,minute,conversation,dies,shape,weight,ergonomic,fit,so,unobtrusive,had,companions,still,wearing,hanging,call,did,n't,shiny,bling,microphone,tip,now,softened,design,BT500,is,still,more,attractive,less,attention,getting,others,headset,work,new,car,has,HandsFreeLink,feature,unit,home,years,still,works,great,headset,reservation,Disclosure,Nokia,not,tested,other,phone,models
#
# always,have,use,lot,features,Razr,recommend,Positives,light,weight,small,size,speaker,phone,works,well,display,is,easy,see,voice,dial,is,accurate,is,great,conversation,piece,Negatives,Speakers,normal,speaker,not,clear,sounding,Nokia,IR,port,has,USB,port,not,software,use,even,charging,phone,battery,life,little,short,video,recording,time,way,too,short,difficult,find,name,address,book,lot,keystrokes
#
# person,said,review,phone,is,thin,is,too,bulky,handle,seems,flimsy,not,disagree,more,feels,extremly,sturdy,is,not,tiny,phone,is,very,thin,weighs,more,then,expect,n't,mind,feels,bit,more,well,made.I,had,version,Motorola,V557,had,well,year,now,got,free,gave,friend,needed,phone,badly,cingular,customer,was,wanting,new,phone,anyways,worked,well.I,got,Nokia,weeks,ago,say,is,good,deal,price,just,did,n't,like,returned,got,razr,spent,bit,more,razr,was,reasonable,razor,is,simple,phone,good,phone,comes,very,pretty,case,make,happy,time,has,good,quality,camera,'s,NOT,digital,camera,more,good,quality,cam,very,easy,read,dial,everything,is,so,clear,spaced,nicley.I,got,black,version,named,KIT,night,rider,car,reminds,dork,had,read,complaints,phone,did,n't,come,enough,stuff,well,'s,launch,price,point,say,was,overpriced,Now,has,come,down,is,good,deal,book.I,very,pleased,so,far,Pleased,enough,come,review,also,cool,accessories,get,including,vynle,sp,skins,color
#
# very,impressed,headset,set,was,simple,SE,K700i,phone,just,paired,devices,added,handsfree,mode,headset,is,light,extremely,comfortable,ear,Just,move,gel,earpiece,left,right,ear,additional,comfort,Conversely,move,gel,earpiece,right,left,ear,fits,so,well,ear,n't,have,need,use,ear,loop.The,sound,clarity,is,great,Everyone,says,very,well,just,needed,raise,volume,little,hear,everyone,perfectly,n't,hear,static,whatsoever,headset,wifi,networks,home.Plantronics,gives,lot,charging,options,SE,charging,adapter,snapped,bottom,little,pocket,case,use,charger,gadgets,headset,comes,Nokia,Samsung,Siemens,Sony,Ericcson,adapter,charging,headset,also,comes,own,charger,case,n't,own,phone,models,use,wall,outlet,tried,method,charging,works,fine,too.This,headset,also,comes,mobile,charger,case,AAA,battery,did,n't,try,method,charging,SE,car,charger,works,well,included,SE,adapter.Voice,dialing,works,fine,'s,important,mobile,professional,spends,lot,time,traveling,car.The,headset,does,beep,right,call,also,beeps,right,signals,name,call,n't,find,irritating,other,reviewer,mentioned,'s,just,headset,operates,let,emphasize,headset,works,great.It,is,best,bluetooth,headset,ever,owned
#
# previous,user,Logitech,Mobile,Freedom,headset,lost,dropping,movie,theatre,many,others,so,know,bluetooth,headset,be.First,impressions,liked,size,headset,spiffy,metal,case,store,included,trinklets,even,mirror,back,case,so,see,cool,headset,box,'s,easy,setup,Took,hrs,charge,headset.Pros,headset,is,light,small,well,designed,ear,gel,is,n't,intrusive,old,Jabras,say,'s,earphone,use,mp3s,'s,made,rubber,is,good,n't,slip,other,gels,default,does,n't,fit,small,set,ears,default,is,perfect,pairs,easily,LG,PM,Sprint,Phone,n't,notice,difference,old,Logitech,terms,sound,quality,meaning,quality,is,excellent,heard,heard,was,clear,static,get,static,'s,just,downfall,BT,technology,wi-fi,walls,microwave,interference,also,comes,different,charging,attachments,Motorola,Nokia,Siemens,Sony,Eriksson,also,use,power,adapter,works,well,pen/marker,sized,charger,put,n't,see,using,AAA,battery,option,charge,'s,great,be,able,charge,anywhere,need,be.Cons,Well,here,is,was,wind,guard,be,great,feature,have,'s,so,mobile,n't,be,better,use,outdoors,Foam,is,n't,that,expensive,add,Secondly,have,been,noise,reduction,feature,Trust,pick,everything,dishes,back,people,talking,stereo,blah,blah,Oh,well,Otherwise,'s,great,Other,price,is,biggest,con,got,here,J,R,had,Ridiculous,Even,is,high,BT,headset,days,hey,look,feel,fit.If,n't,care,obtrusiveness,get,Logitech,Mobile,Freedom,'s,cheaper,thing,was,different,is,Logitech,finishing,call,sometimes,disconnect,phone,BT,connection,was,annoying,wanted,make,call,right,away,plantronics,n't,have,issue,is,awesome
#
# Using,Nokia,N97,left,mount,side,covers,botton,right,mount,side,presses,camara,botton,installing,unlock,application,issue,ulock,botton,got,solved,solve,camara,problem,material,had,be,cut,out.Update,Works,great,iPhone,even,protective,leather,casing
#
# ...
#
# Now,Spring,is,rolling,was,glad,get,opportunity,review,phone/GPS,mount,received,review,sample.The,handlebar,mount,is,pretty,standard,locks,oval,thumb,screw,phone,grip,is,giant,plastic,clip,silicone,pads,clip,opens,real,wide,grip,anything,up,inches,old,Samsung,usually,biking,Nokia,gripped,securely,n't,fall,phone,clip,is,connected,handlebar,mount,plastic,ball,joint.All,mounts,grips,secure,mounted,properly,Most,importantly,silicone,grip,pads,phone,is,pretty,secure,ball,joint,means,rotate,phone,angle,joints,mount,configure,phone,face,many,ways,Also,clip,is,pretty,generic,clip,wallet,rolled,towel,other,small,item,it.I,caution,due,plastic,construction,screws,not,be,tightened,mount,be,checked,cracks,time,current,price,due,utility,item,strongly,recommend
#
# Eachine,Xpower,X3,mAh,power,bank,has,very,slim,attractive,design,soft-touch,plastic,shell,mdash,really,way,feels,hand.The,color-contrasting,cables,sides,get,lost,easy,remove,separate,cable,is,also,included,mini,USB,30-pin,Apple,Nokia,power,bank,was,delivered,fully,charged,recharges,overnight,powered,USB,port,wall,auto,charger,has,four-LED,capacity,display,%,increments,A,ports,smart,circuitry.The,mAh,battery,provide,least,mAh,usable,capacity,using,conservative,%,efficiency,factor,recharge,iPhone,Kindle,Paperwhite,least,times,give,big,boost,small,tablet.Don,forget,press,button,initiate,device,charging.Eachines,provided,sample,testing,unbiased,review
# battery,pack,is,almost,identical,size,shape,iPhone5,has,silk,black,finish,is,somewhat,rubbery,blue,LED,lights,much,juice,is,left,battery,pack,be,recharged,%,mAh,Theoretically,be,able,fully,charge,iPhone5,times.Outputs,Total,outputs,built-in,microUSB,cable,USB,USB,out.Compatibility,comes,own,built-in,input,output,cord,only,need,microUSB,tip,n't,have,bring,extra,cable,covered,also,includes,separate,microUSB,cable,connector,tips,30-pin,Apple,devices,miniUSB,Nokia.Other,lousy,packaging,is,nice,looking,power,bank,is,very,portable,Size,shape,is,just,perfect,throw,purse,emergency,power,it.A,sample,product,was,sent,review,purposes
#
# Eachine,Ultra-slim,X3,charger,makes,happy,'s,so,light,compact,size,cell,phone,tuck,pocket,emergency,charges,has,smooth,sure-grip,surface,built,USB,Micro,B,plugs,so,never,carry,extra,cord,charging,also,comes,extra,charging,tips,Mini,B,Apple,Nokia.It,does,n't,have,power,bigger,chargers,'s,good,maybe,short,charges,phone,charges,recharges,quickly,color,case,is,quite,wonderful,too
#
# is,big,capacity,mAh,power,bank,USB,charging,slots,slot,rated,cell,phones,other,small,electronics,other,tablets,iPads,also,incorporates,LED,lamp,use,emergency,flashlight.The,cool,thing,power,pack,is,LCD,panel,gives,exactly,much,juice,is,left,percentage,also,gives,slot,is,being,used,turn,flashlight,quickly,press,button,times,same,turn,off.Included,is,microUSB,cable,several,adapter,tips,Also,included,30-pin,Apple,connector,miniUSB,Nokia,adapter,short,manual,Made,China.A,sample,product,was,sent,review,purposes
#
# had,ton,Power,Banks,pass,way,last,months,reality,is,one,has,crossed,path,has,been,able,charge,Lumia,old,Blackberry,iPhone,problem,had,varying,capacities,so,on.The,Eachine,is,definitely,nicer,ones,received,helps,make,stand,is,fact,very,few,others,had,is,nice,LCD,display,show,actual,percentage,battery,power,left,Power,Bank,Usually,just,get,few,lights,indicate,never,really,knowing,just,much,final,light,really,is,left,recharge,now,more,cycle,more,guessing,here.The,other,nice,thing,is,price,mAh,external,battery,LCD,capability,Definitely,sets,others,had,still,have.Also,making,stand,is,included,tips,None,others,used,price,range,offered,USB,Micro,USB,mini,plug,adapter,be,clear,make,micro,USB,cable,plug,mini-USB,chargeable,device,also,includes,Micro,USB,older,style,iOS,charger,lightning,included,is,also,Nokia,adapter,older,Nokia,phones,n't,test,out,Still,usually,just,get,cable,charge,Power,Bank.The,capacity,given,general,efficiency,recharging,net,roughly,full,charges,iPhone,Lumia,get,4-5,recharges,is,normal,Power,Banks,Physics,be,darned,Also,nice,is,charge,devices,once,is,n't,recommended,charge,devices,charge,Power,Bank,same,time,affect,negatively,life,expectancy,Power,Bank,comes,portability,one,is,n't,too,bad,mAh,worth,batteries,means,'s,kinda,heavy,not,overly,so,easily,fit,back,pocket,hand,bag,emergency,charge,needed.It,also,includes,flashlight,'s,bright,enough,see,dark,'s,not,great.Overall,is,great,power,bank,good,features,sets,pack.Highly,recommended.I,received,free,sample,review,purposes,manufacturer
#
# is,rather,big,mAh,capacity,power,pack,compact,form,is,very,plain,clean,looking,making,nice,companion,son,white,iPad,mini,LED,flashlight,be,turned,turned,pressing,button,twice,backlit,LCD,panel,is,bright,gives,exact,battery,level,remaining,charge,devices,time,USB,slot,tablets,slot,cellphones,smaller,electronics,MP3,player,etc.Accessories,comes,microUSB,cable,connector,tips,30-pin,connector,older,Apple,devices,miniUSB,Nokia,8-pin,Lightning,tip,is,included,same,microUSB,cable,charge,battery,pack,as,well,charging,devices,connector,tips.Cons,only,gripe,is,poor,packaging,have,been,nice,thing,wrap,present,has,better,packaging.I,rating,stars,features,capacity,minimalistic,look,affordable,price,time,review,.A,sample,product,was,sent,review,purposes
#
# fantastically,impressed,chargers,received,Eachine,X2,is,everything,hope,sturdy,all-around,charging,device,'s,bit,bigger,heavier,X4,'s,miles,ahead,terms,power,'s,charged,phone,dozen,times,Kindle,Fire,least,twice,full,charge,charging,time,tablet,is,n't,nearly,as,fast,direct,connection,A2,connector,'s,fast,enough,make,happy,is,charger,take,trip.The,X2,other,Eachine,chargers,tried,comes,USB,Micro,B,cord,extra,connector,tips,Mini,B,Apple,is,Nokia,connector,has,bright,easy-to-read,LED,display,shows,remaining,charge,output,plugged,'s,latter,is,charge,Kindle,Fire,display,is,activated,device,button,Press,hold,turns,Press,twice,turns,bright,LED,flashlight,located,just,input,turns,flashlight,back,off.Clearly,lot,thought,has,gone,Eachine,chargers,well-designed,versatile,X2,is,real,workhorse,group,Very,impressive
#
# Eachine,is,intents,purposes,exactly,same,Eachine,battery,more,powerful,only,few,bucks,more.Both,several,selling,points,bright,LCD,backlit,screen,displaying,current,battery,level,status,USB,outputs,most,importantly,internal,power,regulating,chip,prevents,overcharging,overloading,short,circuits,side,flashlight,function,is,bright,enough,spotlight,illumination,dark,environments.The,unit,weighed,ounces,has,heft,Not,really,something,slip,pocket,certainly,light,enough,backpack,traveling,rectangular,shape,also,fit,nicely,large,purses,uploaded,photo,pack,next,PSP,get,relative,sense,size.The,packaging,instructions,specifically,state,is,compatible,Various,lighting,Apple,Products,original,Apple,Lightning,USB,cable,as,well,specific,pin,adaptor,provided,iPhone,HTC,Phones,Samsung,Phones,Blackberry,Motorola,Nokia,comes,specific,DC2.0,connector,LG,Sony,Google,Nexus,Nexus,Amazon,Kindle,Fire,HD,DX,other,kindles,others,such,Nook,Tablet,Portable,WiFi,PSP,NOT,PS,Vita,not,listed,instructions,on-site,description,does,state,power,bank,is,NOT,COMPATIBLE,iPod,Nano,Samsung,Asus,tablets,few,other,sundry,GPS/Bluetooth,devices,Which,is,unfortunate,Samsung,Tab,tried,does,not,work,reliably,Tab,However,not,hit,does,specifically,state,is,n't,supported,also,tried,iPod,Nano,did,charge,full,yet,LCD,screen,did,not,register,discharge,rate,take,note,few,categories,does,n't,support,apparently,it.Now,reference,particular,PSP,power,bank,does,not,come,requisite,adapter,USB,charging,cables,PSP,available,here,Amazon,work,power,bank,bought,aData,Power,USB,Cable,Sony,PSPand,used,battery,pack,charm,even,playing,games,video,pack,charged,PSP,was,completely,dead,full,hour,only,%,'s,juice,Now,play,power,hungry,Final,Fantasy,games,impunity,also,tested,power,bank,Portable,Wi-Fi,Verizon,Jetpack,older,Kindle,Keyboard,were,recharged,timely,manner,internal,chip,automatically,stopping,power,output,were,intents,purposes,still,shame,Samsung,Tab,not,being,supported,yet,is,excellent,battery,honestly,model,few,dollars,more,get,Clint,Eastwood,powerhouse,n't,resist,pun,P,received,complimentary,review,product,aim,hopefully,elucidating,features,drawbacks,help,ultimately,decide,fits,needs,budget,best,questions,feel,free,ask,be,more,happy,answer,even,YouTube,video,demonstration,possible,particular,aspect,like,clarification
#
# ZEETRON,selected,clever,name,portable,USB,charger,is,bulky,key,chain,contents,rubber,Hippo,services,compact,serves,connector,charging,USB,end,devices,using,USB,headed,Lightning,USB,iPhone,iPod,devices,micro,USB,Samsung,Nokia,HTC,Blackberry,LG,devices,only,item,missing,kit,is,charging,source,course,power,banks,wall,chargers,car,chargers,floating,around,everyone,has,plenty,sources,power,just,not,enough,readily,available,connectors,little,gadget,helps,problem,Take,anywhere,charge,multiple,devices,car,trip,Works,well,is,clever,boot,Grady,Harp,June
#
# been,using,car,charger,had,been,purchased,use,Kindle,also,works,Nokia,phone,only,had,USB,port,found,charger,was,tad,loose,cigarette,lighter,think,was,charging,something,sometimes,find,nothing,had,happened,had,come,just,enough,not,be,contact.This,is,solid,fit,power,indicator,light,comes,let,know,'s,seated,properly,matter,fact,got,put,little,effort,pulling,was,provided,sample,review,so,happy,got,try,port,is,larger,items,tablets,middle,port,small,devices,third,port,things,MP3,players,not,so,sure,n't,plug,phone,MP3,player,slots,phone,does,give,error,message,recharge,plugged,tablet,port.It,really,nice,have,ability,charge,more,device,time
#
# is,nice,mount,using,Nokia,has,be,able,handle,size,weight,large,smartphone.It,does,just,that.Place,Nokia,mount,mounted,windshield,full,size,pickup,Went,long,road,trip,see,fireworks.It,stayed,put,windshield,kept,expecting,fall,windshield,did,not,also,expected,mount,give,way,slowly,move,downwards,.but,did,not.The,final,BIG,selling,feature,is,phone,mount,little,pressure,side,arms,place,.so,spilled,phone.So,based,needs,expectations,mount,well,pay,reasonable,price,get,reasonably,constructed,mount.free,sample,provided
# HTC,phones,last,year,One,m7,year,m8,NOT,affiliated,HTC,compensated,way,just,feel,competition,underdog,companies,crucial,essential,healthy,free,market,economy,ultimately,consumers,had,iPhones,Samsung,Galaxy,S3/S4,Note,several,Nokia,n95-97,n84/85,several,lesser,phones,Sony/Sony-Ericsson,Xperia,phones,years,loved,most,healthy,positive,technological,evolution,small,struggling,companies,HTC,succeed,Apple,Samsung,become,duopolies,be,dark,future,indeed,Pick,HTC,One,M7,M8,Samsung,Galaxy,phones,compare,quality,craftsmanship,tell,'s,Samsung,not,HTC,more,successful,phones,'s,MONEY,marketing,bigger,guy,trying,squeeze,smaller,guy,'s,NOT,healthy,free,market,economy,be.Now,is,way,let,get,nitty,gritty,is,direct,comparisons,iPhone,Samsung,Galaxy,S4/S5,Note,mainly,last,HTC,One,M7,mainly,updating,keypoints,m7,review,.Keep,mind,is,is,EXCLUSIVE,Sprint,version,is,different,includes,Harmon,Kardon,audio,hardware,tweaks,called,Clari-Fi,details,later,review,pair,Harman/Kardon,AE-S,In-ear,Headphones,retails,separately.The,Good:1,SCREEN,was,such,better,screen,phone,not,yet,seen,iPhone,is,lauded,excellent,screen,current,resolution,trails,One,screen,far,Everything,just,POPS,Even,direct,sunlight,everything,is,CLEAR,BRIGHT,really,loved,HTC,One,M7,screen,once,again,HTC,has,outdone,given,true,masterpiece,form,main,difference,M8,M7,is,color,reproduction,M8,is,better,more,true-to-life,is,BEST,screen,planet,right,now,WOW,DESIGN/HARDWARE,Once,again,new,continues,HTC,tradition,making,really,high-quality,phones,high-class,material,craftsmanship,version,has,more,matted-brushed,aluminum,finish,glossier,M7,feels,THICK,TOUGH,n't,have,worry,carrying,case-less,drops,is,whole,other,issue,not,be,worried,phone,nicking,scraping,iPhone,Personally,not,have,flair,Sony,Nokia,phone,past,totality,One,has,best,combination,design,craftsmanship,oozes,style,sophistication,plastic-y,feel,Samsung,Galaxy,S4/S5,is,real,looker,DUAL,FRONT-FACING,SPEAKERS,been,desensitized,modern,smartphones,nowadays,crappy,tinny,mono,speaker,days,Nokia,n95,n84,stereo,speakers,happened,phones,agreed,mono/solo,speaker,smartphones,thereafter,FINALLY,someone,has,senses,come,back,reality,thank,HTC,Trust,ears,thank,realize,phones,have,been,made,Especially,ringtones/alerts,were,specifically,created,phone,sound,is,loud,immersive,expansive,POPs,ears,'s,simply,re-revolution,Compared,M7,M8,loses,Beats,audio,engineering,actually,sounds,louder,M7,has,really,high-quality,speakers,well,was,known,being,too,soft,certain,scenarios,new,moniker,is,just,BoomSound,*,exclusive,Sprint,version,includes,audio,hardware,tweaks,Harmon,Kardon,helps,make,audio,even,better,Let,explain,as,concisely,possible,works,days,CD,music,track,was,50-100mb,sound,was,not,so,compromised,advent,mp3s,size,were,shrunk,down,5-10mb,song,sound,was,still,good,tell,something,was,missing,get,size,audio,was,compressed,so,parts,edges,highs,lows,chopped,still,decent,sound,just,not,full,high,fidelity,CD,DVD-caliber,files,Clari-Fi,tries,ameliorate,filling,chopped,portions,create,richer,fuller,sound,reality,notice,better,sound,certain,types,mp3,compressed,music,ones,heavily,compressed,such,kbps,bit,rates,opposed,something,fuller,higher,notifications/ring,tones,Internet,audio,not,notice,so,much,Nonetheless,is,welcome,upgrade.Secondly,free,pair,Harman/Kardon,AE-S,In-ear,Headphones,selling,currently,really,good,earbuds,far,much,much,better,anything,get,included,standard,phones,read,more,[,harmankardon.com/estore/hk/us/products/AE/HARKAR-AE_HK_US,],.4,THE,CAMERA,n't,use,phone,camera,make,prints,photos,dedicated,cameras,So,paramount,function,phone,cameras,is,convenience/accessibility,has,be,able,capture,quickly,clearly,decent,enough,quality,post,online,Therefore,size,One,camera,does,not,bother,cares,camera,is,n't,THE,BEST,phone,camera,ever,is,not,is,GREAT,low-light,shooter,'s,more,important,pixel,count,sensors,camera,bigger,other,phone,cameras,therefore,capture,lot,more,light,laymen,terms,give,better,photos,more,situations,other,phone,cameras,Also,touch,spot,focus,is,almos ...
#
# eBOOT,pays,attention,needs,customers,most,people,portable,power,bank,several,versions,customer,choose,power,bank,most,adaptabe,needs.This,small,very,powerful,resource,charging,quickly,capacity,protective,features,needed,built,protection,overcharge,overvoltage,overcurrent,short,circuit,battery,is,reliable,Samsung,Li-ion,charging,power,cord,USB,bank,widespread,adaptabiliy,is,excellent,rapidly,charges,Android,Tablets,Phones,iPhone,iPad,Air,Mini,Samsung,Galaxy,S4,S3,S2,Note,Kindle,Fire,HD,HDX,Google,Nexus,Motorola,Droid,Razr,Maxx,Moto,X,HTC,X,V,S,LG,G2,Nokia,Lumia,PS,GoPro,Bluetooth,Speakers,Headsets,External,Battery,Packs,Power,Bank,Other,USB,Charging,Electronic,Battery,n't,think,left,anything.Stylish,small,enough,fit,pocket,purse,still,be,unnoticed,is,terrific,unit,price,is,hard,beat,Great,gifts,Grady,Harp,July
#
# useful,emergency,power,backup,cell,phone,wife,is,using,emergency,backup,Nokia,Kept,purse,provides,backup,is,work,plug,phone,continues,make,rounds,mobile,work,life,not,just,sit,plug,outlet.I,received,free
#
# 1484

# %% [markdown]
# <h3>Testing:</h3>
#
# - Query and check that all the Nokia reviews have the newly-added record.

# %%
from pymongo import MongoClient
import re

bdb = ""
try:
    connection = MongoClient("mongodb://localhost:27017")  # Connection String
    db = connection.amazon
except:
    print("Something went wrong!")

regx = re.compile("Nokia", re.IGNORECASE)
cursor = db.reviews.find({"reviewText": regx}, {"reviewText": 1, "keywords":1})

for e in cursor:
    print(e['keywords'])
    print()
# Out:
# got,pair,Plantronics-branded,headsets,Verizon,OEM,packaging,plastic,bag,coming,universal,adapter,micro-USB,male,female,price,was,substantially,same,unit,is,small,issue,sets,pictures,product,different,units,right,plastic,bag,is,clearly,labeled,MX150xxxx,identical,Note,obvious,button,showing,plastic,mutes,turns,call,voice-dials,Blackberry,do,other,things,other,models,However,other,photos,same,headset,control,button,not,different,button,nothing,made,wonder,is,being,sold,MX150,other,issue,is,color,'s,not,clear,black,gray,even,is,choice,photo,assume,dealer,supply,gray,ones,not,so,sure,is,not,exactly,item,buys,style,points,'s,compact,looks,bulky,face,'s,minor,point,be,good,have,clarity.But,as,far,product,goes,'s,perfectly,functional,purpose,cheap,branded,headset,specifically,complement,BT,set,one,replaces,charge,runs,had,number,cheap,free,headsets,often,even,enclosed,phone,virtually,awful,raspy,tinny,sound,'s,not,headset,even,needed,emergency,headset,bill,sound,quality,is,far,superior,no-name,headsets,ends,'s,better,average,Sony/Ericsson,handset,always,headset,using,Sony,deliberately,puts,crappy,speakers,Ericsson,phones,make,buy,headsets,traveling,NY,DE,other,state,requires,no-hands,phone,is,essential,be,quickly,disconnect,replace,discharged,BT,headset,qualms,using,one.UPDATE,months,later,got,sets,friend,fit,phone,rejected,not,compatible,was,cheap,ATT/Nokia,handset,replace,lost,phone,so,not,surprised,compatibility,issues,also,meant,got,extra,set,month,ago,sets,died,phone,got,yanked,too,hard,probably,loose,contact,less,had,problem,tossing,pulling,next,one,still,more,left,having,spent,total,including,shipping,So,aside,Nokia,compatibility,still,complaints
#
# ..and,Europe,phones,networks,much,better,States,say,Samsung,currently,best,software,used,be,huge,Nokia,fan,Amazingly,light,very,intuitive,great,audio,just,looks,great,reservations,whatsoever
#
# phone,was,purchased,T-Mobile,plan,replace,Nokia,phone,AT,amp,T.,changed,phones,service,old,phone,not,get,reception,buildings,chose,V300,due,external,antennae,had,phone,weeks,now,been,very,pleased,reception,is,bit,tinny,sometimes,overall,not,had,problems,dropped,calls.I,text,message,quite,frequently,phone,offers,choices,writing,text,first,is,intuitive,text,entry,method,phone,guesses,words,trying,type,displays,screen,choose,method,is,supposed,save,time,not,yet,gotten,hang,second,method,is,tried,true,press,button,letter,method,only,problem,phone,is,buttons,not,same,shape,spaced,makes,text,messaging,bit,trickier,first,numbers,letters,written,buttons,very,light,often,shift,angle,phone,order,just,read,buttons,light,text,also,be,issue,someone,vision,problems.Overall,recommend,phone,only,reason,gave,stars,instead,is,Motorola,needs,darken,text,buttons,users,text,message,vision,problems
#
# Positives,Bluetooth,IR,port,VGA,Camera,multiple,e-mail,accounts,speaker,phone,more,programs,becoming,available,Symbian,O/S,wireless,headset,make,phone,serve,wireless,modem.Negatives,phone,too,big,voice,recognition,worthless,low,volume,ear,piece,IR,port,weak,so,TV,remote,control,programs,n't,work,well,slow,menu,response,Get,Opera,browser,phone,does,not,come,WAP,browser,only,frustrate,Opera,has,problems,phone,works,most,time,T-Mobile,programmed,backlight,display,turn,few,seconds,Nokia,made,adjustable,T-Mobile,n't,fix
#
# OPERATION,'s,BMW,I-Drive,does,'s,job,has,most,unintuitive,overly-layered,interface,example,memory,card,is,battery,phone,be,shut,taken,apart,change,memory,card,turning,phone,back,takes,little,while,is,representative,entire,phone,operation,Not,impatient.If,never,used,advanced,mobile,phone,assume,is,par,course,simply,is,n't,Even,instruction,booklet,is,order.APPLICATIONS,has,lots,applications,very,well,eventually,finally,matter,accustomed,phone,too,much,time,is,required,get,open,close,applications,other,hand,leave,many,applications,once,hide,return,just,left,similar,Mac,Me,likes.The,has,more,ameneties,most,World,phone,Camera,VGA/zoom/night,mode/timer,Video,w/,audio,zoom,Speaker,good,sound,Bluetooth,infrared,Modem,computers,electronic,wallet,Internet,access,Calendar,calculator,converter,more.The,phone,does,not,have,Mp3-player,FM,radio,color,screen,megapixel,camera,quad,band,PDA,photo,editor,not,sure,phone,w/,above,features,exists,just,yet,not,sure,want,spend,THAT,much,time,w/,device,anyhow.DEPENDABILITY,seen,glitches,had,problems,phone.STYLING/ERGONOMICS,keys,small,generally,does,n't,bother,spaced,employ,little,'Braille,keys,other,so,careful,attn,be,paid,dialing.As,appearance,'s,subjective,Few,look,phone,know,'s,'s,not,as,stylized,Sony,Samsung,Less,Benz/obvious,more,has,chubby,hips,device,is,n't,really,so,big,Solid,squeak-free,large,screen.MEMORY/STORAGE,Seemingly,boundless,First,all,phone,houses,great,deal,memory,multiple,videos,sound,clips,photos,texts,Secondly,info,be,sent,computer,w/o,hassle,USB,wires,Still,not,sure,phone,memory,sent,computer,is,memory,card,w/a,good,deal,storage,as,well,is,small,deal,still,whining,storage,deleting,games,free-up,still,more,memory.RECEPTION,really,depends,locale,carrier,T-Mobile,is,true,'world,phone,has,mhz,operate,globe,including,New,Zealand,Australia,available,Cingular,replaces,w/,latter,provide,better,coverage,more,remote,areas,States,still,operates,many,countries,excluding,New,Zealand,Australia,provide,similar,service,more,developed,areas,States,not,as,well,more,remote,areas,uses,operates,more,countries,battery,life,is,less,stellar,charges,quickness,Remember,phone,uses,operating,system,Symbian,'s,feature-rich,w/,colors,films,second,video,crying,loud,battery,life,n't,be,very,long,let,not,be,greedy.GAMES,Java,n't,use,so,addtl,space,humble,opinion,games,w/,phones,belong,hands,teenagers.IMP,important,pieces,advice,Visit,Nokia,site,number,downloads,needed/available,phone,be,texted,cost,downloads,basic,advanced,operations.The,second,piece,advice,Be,prepared,spend,lot,time,w/,phone,be,able,pick,things,rush,common,sense,many,times,end,frustrated,Sony,Ericcson,be,phone,good,luck,finding,w/,features,competitive,price,Keep,mind,nearly,screen,number,'along,side,'beneath,choices,phone,memory,memory,card,sim,card.Despite,critical,start,phone,deserves,stars,accomplishes,sets,do,is,pretty,lofty,does,more,most,does,well,is,dependable,'s,high-line,Audi,Cadillac,suspension,reasonable,price.When,expandability,downloads,computer,numerous,features,transmission,programs,multiple,storage,devices,dependability,is,phone,is,n't,easy,out-grow.I,suggest,phone,simple-minded,simply,n't,need,so,many,features
#
# been,waiting,finish,year,contract,get,phone,i,did,find,bad,reviews,let,tell,folks,awesome,phone,Palmone,T3,i,really,having,good,time,now,neeed,try,sync,option,soon,i,much,satisfied,giving,stars,keys,placed,little,odd,thanks
#
# been,months,now,held,Nokia,purchased,phone,knowing,was,slightly,old,compared,newer,models,Nokia,phones,available,thought,was,kind,steeply,priced,time,add,dismay/delight,readers,phone,is,simply,most,groundbreaking,phone,mankind,has,ever,held,has,raised,bar,owing,number,features,offers,absolute,ease,use,delight.Now,techy,getting,technical,things,so,brief,few,features,liked,phone-1.The,Phone,has,best,keypad,Nokia,phone,has,offer,dad,has,Nokia,has,Nokia,had,Nokia,keypad,cell,phone,is,most,important,thing,Im,constantly,sending,messages,calling,people,fiddling,around,phone,Believe,used,fingered,Nokia,phones,has,best,keypad2,looks,absolutely,nonsensical,being,tad,too,bulky,looking,admit,not,best,looking,phone,ever,then,has,look,static,absolute,conviction,looks,everything,phone,be3,Nokia,has,brilliant,Java,interface,'s,whole,lot,things,do,phone,reading,book,playing,various,Java,games,having,variety,software,installed,Phone,offers,Mb,MMC,card,is,certainly,most,exciting,feature,upgraded,mine,MB,MMC,Card,store,unlimited,number,messages,thousand,pictures,videos,Capacity,is,not,problem,here.4,Build,is,just,right,phone,is,sturdy,dropped,dozen,times,recolletion,still,works,as,good,ever,tough,one,na,drive,car,is,n't,most,rugged,phone,ever,then,not,gon,play,aeroplane,you.5.The,Camera,installed,phone,is,awesome,pictures,JPG,format,phone,has,bluetooth,device,extremely,easy,transfer,pics,pc,forth,display,brightness,phone,is,quite,extraordinary,use,colors,ensures,get,share,animations,icons,phoneBesides,above,mentioned,Merits,phone,has,decent,ear,volume,loudspeaker,functionality,has,great,upgradibility,play,MP3,files,phone,simply,downloading,softwares,freely,available,net,Now,is,neat,log,functions,incoming,outgoing,calls,most,easy,ways.The,handsfree,provided,phone,is,useful,phone,driving,n't,do,'s,not,worth,life.Anyhow,demerits,phone,phone,has,slow,processor,ear,volume,is,lower,then,has,best,ear,volume,most,Nokia,variants.The,battery,life,phone,is,most,days,least,day,excessive,use,Video,recording,is,limited,just,seconds,upgrade,then,'s,certain,level,trouble,involved.Overall,ever,upgrade,phone,purchased,phone,thought,myself,had,purchased,most,popular,phone,around,thought,did,n't,please,case,putting,common,is,city,be,anymore,satisfied,makes,great,phone.Did,note,feature,send,notes,Bluetooth,gee,anyways,ENJOY,WHAT,WORKS
#
# received,little,gem,Christmas,now,speak,phone,BT,enabled,unit,is,perfect,gift,anyone,cell,phone.No,more,complicated,setups,As,soon,turned,Nokia,found,recognized,associated,was,speaking,it.The,battery,life,is,great,clarity,is,also,dead,on.Once,product,too,never,go,back,speaking,phone,old,fashioned,way
#
# Pros,function,design,headset,first,rate,Right,box,was,easy,pair,Motorola,v505,phone.It,is,small,unobtrusiveThe,battery,life,is,really,good,standby,mode,lasts,several,hours,talking,does,issue,warning,tones,battery,runs,low,phone,issues,message,saying,headset,signal,weak,switch,handset,combo,belt,clip/charger,is,really,cool,idea,have,been,EVEN,COOLER,Jabra,had,made,compatible,nokia,Moto,Ericsson,phone,chargers,Now,yet,ANOTHER,power,supply,drag,trips,.Reception,is,very,good,as,long,line,sight,is,unobstructed,anything,full,water,pump,gas,car,phone,passenger,seat,wander,hotel,suite,waving,arms,wildly,phone,sits,charging,stand,desk,is,body,way,aquarium,then,signal,drops,attenuates,dramatically,fact,is,marked,difference,putting,phone,opposite,side,body,earpiece,carrying,phone,pocket,opposite,side,signal,degrades,noticeably.The,Cons,been,unsuccessful,getting,pair,laptop,PDA,however,HP,iPaq,.If,bluetooth,PDA,use,BT,Activesync,PC,interfere,headset,is,connected,Activesync,perspective,hear,constant,crackling,noise,sounds,other,person,is,popping,popcorn,took,while,figure,n't,have,turn,BT,radio,laptop,PDA,just,disconnect,BT,session,temporarily,talking,is,hassle,not,killer,reasons,instead,stars,biggest,problem,unit,is,does,not,fit,ears,feeling,very,insecure,hanging,design,always,feels,is,flopping,around,too,far,side,unit,actually,fall,ear,is,way,tighten,fit,unit,already,tried,different,earpieces,positions,earpieces,does,n't,help,is,reason,probably,replace,unit,shame,is,such,nice,unit,floppiness,ears,is,unacceptable.BTW,not,midget,weigh,lbs,fairly,narrow,face,bigger,issue,is,small,earlobes,small,earlobes,rather,pendulous,ones,want,test,fit,unit,store,buying,here,had
#
# phone,is,flashy,feels,good,hand,not,hold,connection,bluetooth,devices,headset,handheld,desktop,computer,old,Siemens,s56,other,hand,worked,beautifully,above.If,web,find,many,websites,people,complaining,lack,drivers,phone,cavelike,silence,Nokia,asked,help.If,needs,limited,making,phonecalls,taking,snapshots,phone,probably,satisfy,Bluetooth,stay,away
#
# owned,versions,unit,Nokia,apparently,requires,specific,type,compared,other,BT,phones,second,one,currently,is,Motorola,V600.This,comparison,cover,Jabra,units,compare,Nokia,HDW-2,Blutooth,adapter,as,well,Motorola,HS-820,bluetooth,adapters.The,jabra,unit,boasts,much,better,design,other,sit,ear,feel,extremely,awkward,jabra,design,provides,much,better,more,comfortable,fit,even,glasses,other,has,flimsy,ear,plastic,pieces,very,place.I,felt,unit,be,relatively,easier,use,compared,other,had,NO,problems,teaming,units,did,have,jump,few,hoops,team,V600.THE,most,important,reason,wanted,BT,adapter,first,place,was,due,fact,i,phone,signal,liviing,room,is,signal,desk,basement,is,directly,living,room,reception,was,same,not,use-able,also,noticed,went,corner,lose,signal,true,units.All,rate,follows,scale,Quality,jabra-4,Nokia-3,Motorola-2.5Design,Jabra-5,Nokia-1,Motorola-1usabaility,range,Jabra-3,Nokia-3,Motorola-3usability,ease,use,Jabra-4,Nokia-3,Motorola-3Overall,Jabra-4,Nokia-2,Motorola-2One,thing,i,did,not,get,test,was,battery,life,Jabra,did,provide,good,half,days,battery,time,single,charge,i,did,not,get,test,battery,life,Nokia,Motorola,units
#
# Paired,nokia,Awesome,headset,battery,life,is,pretty,long,feels,really,light,ear,sound,is,excellent.Some,people,be,going,deaf,something,thing,get,loud,never,volume,max,thing,feels,heavy,ear,have,ears,size,nickels,using,same,ear,i,n't,know.Whenever,sometimes,unit,rings,makes,twitch,not,expecting,ring,blasting,thru,ear.I,hate,-wind,noise,n't,carry,conversation,driving,windows,walking,wind,blowing,face.-voice,dialing,not,work.-it,makes,phone,hang,reset,be,phone,problem,general.-30,feet,more,best
#
# keyboard,fills,left,pocket,Ultra,mobile,PC,phone,fills,right,pocket,keyboard,allows,type,normal,speed,device,keep,pocket,was,astonished,see,have,even,worked,text,messaging,older,phone,Nokia,N-Gage,HTC,phone,phone,supports,keyboard,even,PDA,highly,product,is,costly,Pair,anything,run,TextMaker,Office,WindowsMobile,meeting,powerhouse,pocket,tackle,best,college,note,taking,much,more,mobile,manner,laptop,n't,need,take,bag,plug,otherwise,waste,time,also,pairing,mouse,same,company,same,purpose
#
# Use,Nokia,N95-3,works,very,well.A,bit,bulky,not,really,pocketable,fits,bags,easy,transport.Great,using,airplanes,is,small,not,take,entire,table.Some,keys,very,touchy,noticed,E,button,press,twice.All,very,nice,product
#
# had,SKII,fo,little,month,now,find,good,fit,needs,business,user,not,Snoop,Dog,groupie,is,VERY,cool,device.Coverage,area,Austin,TX,is,good,not,yet,traveled,away,IH-35,corridor,had,good,voice,data,coverage,way,TX/OK,stateline,far,north,went,eat,data,is,screaming,deal,n't,find,web,surfing,useful,speed,is,dial-up,connection,email,is,superior,Blackberry,used,number,years,ago,interface,phone,email,address,book,is,great,Far,better,Nokia,phone,ever,used,intellisync,software,allows,create,use,separate,address,book,Outlook,then,sync,SKII,button,push,Very,simple,means,have,abreviated,address,book,concerned,having,infor,resident,TMO/Danger,servers,reviewier,be,better,info,is,NOT,resident,'s,concern,server.Drawbacks,bluetooth,resident,memory,email,pictures,removable,memory,stick,easy,way,create,use,own,ringtones.Great,things,great,keyboard,nicer/bigger,Crackberry,intuitive,interface/software,screen,size/clarity,Camera,nice,feature,easy,email,pics,anywhere,very,cool,functional,device,phone,email,web,other,stuff,OK,TMO,data,network,have,get,faster,more,WAP,coded,websites,content,is,relevent,be,big,reason,buy/use,device.I,purchased,Danger,website,total,cost,instant,discount,rebates,year,contract,TMO,book,Paying,regional,anytime,minuets,eat,data,email,text,messaging,EVERYTHING,DATA,included,.I,recommend,anyone,really,needs,email,occaisional,web,service,addition,phone,service,Not,smallest/best,coolest,phone,best,convergent,communication,device,market,right,now,IMHO
#
# Got,headset,replace,Jabra,was,incompatable,Nokia,Fit,comfort,is,extremely,subjective,found,Jabra,be,far,more,comfortable,actually,forget,was,wearing,said,unit,is,not,uncomfortable,couple,hours,just,not,nearly,comfortable,securely,fitting.Very,few,complaints,as,far,performance,was,easy,pair,phone,wife,Motorola,V3,even,laptop,Sound,quality,is,clear,parties,recipients,occasionally,complained,pinging,noise,Jabra,noise,reduction,actually,works,eliminate,wind,noise,Battery,life,is,excellent,single,function,be,little,aggrevating,especially,trying,turn,hold,long,time,only,weird,very,rare,quirk,is,occassionally,calls,be,interrupted,strange,sound,sounds,someone,dropping,manhole,cover,spins,pavement,very,strange,very,annoying,fortunately,very,rare.Overall,performance,is,top,notch,comfort,is,acceptable,value,is,difficult,beat
#
# were,exactly,mother,needed,old,Nokia,goes,quickly,got
#
# owned,Palm,type,years,had,cell,phone,slightly,less,time,always,resisted,buying,combined,device,thought,n't,ready,yet,came,time,replace,PDA,decided,Treo,be,ready,had,concerns,size,screen,integrating,PDA,cell,phone,functions,Overall,most,nervousness,was,groundless,pleased,phone,so,far.Good,points,Works,well,phone,Better,signal,Nokia,phone,replacesScreen,is,very,readable,even,is,smaller,traditional,PDAPalm,functionality,is,fine,interface,has,been,redesigned,bit,seldom,stylus,Most,entries,done,rocker,switch,bottom,center,screen,keypad,truly,do,many,functions,one-handed,managed,do,losing,feel,Palm,n't,having,re-learn,zero.The,memory,is,non-volatile,English,means,batteries,dead,n't,lose,data,till,Palm.Bad,points,slight,delay,dialing,number,Palm,contacts,list,right,'s,not,really,problem,is,annoying,couple,second,delay.If,books,Palms,not,sure,screen,do,prolonged,reading.Battery,life,is,fair,able,get,days,medium,use,bit,life,left,battery,Not,days,monochrome,Palms,go,week,recharges,'s,only,so-so,web,browser.The,price,is,hideously,high.Keyboard,is,cramped,as,good,expect,such,small,device,is,definitely,useable,instinct,was,use,right,thumb,only,now,people,hands,only,be,seen,Treo,not,believe,upgrade,be,currently,waiting,make,jump,combined,PDA/phone,is,good,point,do
#
# NOT,get,charge,Did,not,sent,back,cost,more,ship,back,help,got,did,order,Nokia,BL-5C,works,great
#
# was,no,longer,obtain,good,quality,BL-5C,finally,gave,Nokia,phone.I,last,battery,tried,was,actually,had,worse,performance,battery,had,used,year,was,trying,replace.These,be,phonies,China,just,so,old,chemically,inert,afraid,n't,recommend
#
# issues,battery,order,OEM,Nokia,BL-5C,battery,advertised,Nothing,exciting,performance,is,be,new,battery,Price,was,excellent,compared,retail,very,satisfied,purchase
#
# searching,searching,battery,baby,monitor,Levana,BABYVIEW20,found,uses,Nokia,battery,was,too,nervous,buy,type,product,seller,other,Amazon,did,just,works,fits,perfectly
#
# recently,purchased,batteries,four-year-old,Nokia,cell,phones,Based,month,trial,batteries,hold,charge,reasonable,amount,time,much,better,old,batteries,be,good,choice,especially,money
#
# does,n't,have,range,Nokia,headset,i,tried,is,vastly,more,comfortable,used,Samsung,t809,had,issues,couple,days,review,Range,was,feet,supposed,have,signal,fading,was,rapid,Very,light,easy,use,fortunately,mid,signal,tones
#
# bought,H500,few,years,ago,first,came,was,plagued,low,volume,poor,connection,using,nokia,bluetooth,last,year,got,again,cell,phone,laws,California,July,headset,is,plenty,loud,Sony,Ericsson,T650i,n't,had,drop,bluetooth,connection,yet,volume,sits,little,half,hear,perfectly,car,Battery,life,rocks,voice,clarity,is,lot,better,remembered,first,H500.4,stars,ear,clip,is,flimsy,does,n't,allow,H500,sit,tightly,ear,So,planning,using,while,running,intense,walk,n't,count,it.Definitely,recommend,great,device,Ca,n't,go,wrong,price
#
# Right,say,comes,cell,service,phones,inherent,contracts,more,ways,buyer,beware,research,ad,nauseum,getting,new,contract,bed,new,cell,provider,been,Nextel,subscriber,years,i90,i730,lovely,phones,service,very,professional,Nextel,coverage,features,expected,said,researched,death,bought,phones,service,Got,phones,Amazon.I,too,was,taken,looks,RAZR,so,was,wife,saw,was,as,good,looked,was,worth,worth,switching,carriers,Nextel,was,n't,making,easy,stay,got,bed,Sprint,had,Sprint,years,still,have,nightmares,customer,service,price,upgrade,phone,Nextel,was,*unacceptable*,point,view,Everyone,knows,cheaper,phone,new,contact,got,RAZR,local,retailer,sorry,Amazon,rebates,Cingular,n't,effort,paid,best,price,*anywhere,*,got,family,plan,is,par,Verizon,saves,bunch,money,Nextel,A,*bunch*,money,words,rollover,spent,just,hour,charging,phone,reading,manual,configuring,phone,function,as,well,not,better,i730,is,*great*,phone,noticed,similarities,function,detail,quality,Sony,Motorola,Nokia,phones,friends,mine,manual,is,something,many,people,avoid.For,anyone,complaining,phone/,address,book,shame,was,worried,address,book,based,reviews,minutes,manual,using,phone,got,RAZR,do,*everything*,nifty,i730,do,then,so,many,ways,configure,address,book,'s,silly,assign,create,categories,numbers,addresses,even,phone,only,display,certain,categories,only,flip,thru,numbers,flip,thru.As,complaints,battery,life,RAZR,has,six-plus,hour,talk,time,better,phones,market,today,say,cos,researched,phones,market,plug,phone,sleep,night,*guarantee*,be,fully,charged,morning.Fragile,phone,clumsy,beaten,lots,phones,years,expect,just,anything,side,brick,break,Half,i730,is,made,same,material,RAZR,is,has,lousier,belt,clip,boot,has,allowed,i730,fall,ground,way,too,many,times,happy,material,'s,expected,durability,Stop,throwing,delicate,*expensive,*,micro-electronic,device,'s,made,teflon,*Be,careful,*I,not,camera-phone,bandwagon,primarily,is,required,merge,technologies,is,'s,nature,usually,expensive,difficult,good,example,is,ROKR,so-called,iTunes,phone,iPod,phone,had,come,close,actually,blending,best,wireless,world,abilities,iTunes,iPod,have,bought,came,far,short,doing,cos,blending,ideas,is,n't,easiest,thing,pull,well,RAZR,is,not,expensive,has,great,camera,large,memory,stick,capture,full-motion,video,zip,dorm,room,buddies,blink,eye,'s,expensive,'s,*slick*,looking,phone,makes,other,phones,shelf,self-conscious,Most,professional,reviews,phone,gave,low,marks,camera,abilities,so,n't,be,surprised,Want,good,camera,phone,Cingular,Sony,s710,got,great,reveiws,good,luck,getting,less,twice,RAZR,costs,'s,difference.Last,thing,got,phone,knowing,days,send,whole,thing,back,'s,not,working,'s,little,consumer-friendly,cushion,give,time,fully,evaulate,phone,Still,did,research,there,n't,be,too,many,surprises,got,phone.Hope,helps
#
# bought,becasue,was,very,happy,see,phone,metal,case,again,used,just,use,nokia,phones,back,day,break,least,once,month,Bought,Moto,v60,was,really,blown,away,best,phone,ever,had,Then,upgraded,color,phones,tried,other,Motos,Really,big,disapointment,Moto,phones,made,so,cheap,fall,apart,just,nokia,came,jumped,Finally,Moto,was,going,back,quality,phones.PROS,-Some,sturdy,case,metal,parts,solid,marks,yet,month,.-The,battery,life,is,little,tiny,bit,higher,then,average,phone,charge,night,has,least,life,left,about,hours,day.-Camera,is,ok,not,best,far,not,worst.-Slim,form,factor,yes,wider,then,normal,flip,is,good,size,Other,phones,always,seemed,skinny,me.CONS,is,metal,bottom,is,plastic,seems,be,cheap,plastic,creaks,is,antenna,is,has,SAR,rating,.80,ear,then,much,jaw,is,getting,jaw,get,cancer,then,brain,right,-The,vol,is,almost,joke,is,so,low,highest,normal,phone,is,middle,setting,used,have,turn,people,cell,now,struggling,hear,sometimes.-The,keypad,looks,nice,pain,butt,donut,thing,middle,is,already,scracthed,finger,nail,rest,keypad,is,protected,seems,has,marks.-A,pain,clean,keypad,is,shiny,gets,rubber,lining,keys,part,ever,using,gets,looking,even,book,Good,god,man,fact,used,phone,book,really,shows,n't,put,lot,effort,phone,was,total,mess,up,way,is,true,shame.-Good,luck,support,warranty,Moto,Past,experiences,was,very,poor,phone,get,fixed,month,later,back,did,n't,even,read,problem,was,fix,send,still,broken.The,reason,phones,cheap,plastic,opinion,is,do,months,phone,looks,dropped,stairs,few,dozen,times,Strong,durable,plastic,is,used,time,crying,loud,Glad,uses,time,more,then,happy,pay,dollars,quality,money,same,phone,is,not,even,close,meeting,expectations,thought,get,dollar,basic,cell,phone,high,standards,top,dollar,best,Moto,be,seeing,is,offering,good,rebates,now,something,Amazon,now,Well,other,reviewer,Verizon,CDMA,phone,is,only,GSM,ever,make,CDMA,version,course,real,clue,Call,Motorola.Also,sorry,spelling,mistakes,take,much,time,go,back,review,wrote,not,getting,paid,n't,waste,time,Good,luck,be,very,happy,phone
#
# had,phone,while,now,here,'s,User,Interface,has,had,bad,rap,people,'s,not,as,intuitive,say,Nokia,interface,does,have,pros,customize,button,including,arrows,left,right,soft,keys,left,soft,key,programmed,go,Shortcuts,function,right,there,course,while,use,get,used,interface.The,volume,phone,is,decent,problems,hearing,other,people,problems,hearing,Speakerphone,works,great,too,boyfriend,says,longers,feels,'s,talking,someone,tunnel,speakerphone,calls,only,volume,problem,see,is,highest,volume,is,still,slightly,hard,hear,phone,ring,other,thing,phone,has,way,cool,ringtones.The,address,book,issue,is,SIM,card,store,addresses,then,not,be,able,have,multiple,entries,person,phone,memory,store,numbers,have,many,many,numbers,stored,entry,numbers,stored,Powerbook,address,book,not,too,worried,having,SIM,card,MAC,iSync,works,wonders,syncing,numbers/calendars,RAZR,'S,cool,screen,is,very,large,clear,problems,seeing,dark,even,bright,light,had,problems,reception,Cingular,so,far,fact,stronger,signal,most,places,previous,phone,Nokia,Overall,very,pleased,design,functions,asthetics,phone
#
# Sexy,form,CHECK,Innovative,construction,CHECK,Exclusive,price,tag,CHECK,sea,flip,phones,candy,bar,phones,look,alike,RAZR,V3,is,Ferrari,mobile,phones,stands,such,looking,feature,rich,phone,then,V3,is,not,V600,provide,same,features,far,less,high-quality,constructed,phone,screams,look,sexy,b*tch,then,V3,is,alley.Actually,better,analogy,be,Acura,NSX,mobile,phones,NSX,V3,is,marketing,tool,Motorola,'s,way,saying,known,inexpensive,phones,build,stylish,well-crafted,high-end,phones,too,Unless,technology,improves,GSM,V3,is,phone,definitely,keep,more,years,styling,design,construction,is,just,that,good,upgraded,trusty,reliable,yet,mediocre,Nokia,TDMA,phone,'s,been,quite,debate,construction,V3,best,explanation,heard,is,bottom,backside,battery,cover,lower,front,is,plastic,antenna,certainly,makes,perfect,sense,metal,frame,IS,antenna,other,areas,cold,touch,weather,areas,usually,room,temperature,Furthermore,be,misrepresentation,Motorola,part,advertise,such,Regardless,phone,seem,flimsy,'s,very,solid,is,comparison,w/,old,Nokia,girlfriend,V551.Mikey,likeys:1-,mini-USB,port,is,great,single-point,access,data,charging,'s,simple,be,mobile,phone,standard,2-,Bluetooth,connectivity,Coming,wired,hands-free,setup,Bluetooth,headset,Jabra,BT250,is,godsend,leave,V3,charging,home,office,still,be,connected,living,room,SIDE,NOTE,stay,away,D-Link,Bluetooth,USB,adapter,PC,connectivity,get,Belkin,F8T001,adapter,read,review,D-Link,details,Quad,band,Doubtful,ever,use,feature/benefit,words,certainly,impress,speakerphone,been,non-believer,mobile,phone,speakerphones,got,admit,V3,speaker,phone,is,bomb,'s,loud,clear,not,loud,enough,car,girlfriend,tells,better,V3,speakerphone,old,Nokia,wired,headset,setup,n't,have,Bluetooth,headset,spoiled,speakerphone.5-,internal,display,Going,V3,Nokia,is,leap,spacial,proportions,couple,weeks,found,be,spoiled,w/,large,internal,display,not,only,V3,has,ATI,IMAGEON,graphics,accelerator,other,phones,excluding,PDA,phones,comparison,regard.Mikey,no-likeys:1-,No,memory,expansion,n't,see,using,internal,memory,SD/MMC,card,expansion,slot,be,nice,Maybe,Motorola,somebody,else,maybe,come,mini-USB,adapter,purpose.2-,Poorly,written,owner,manual,found,owner,manual,is,more,reference,manual,sometimes,leaves,figuring,things,own,does,not,explain,use,many,common,features,owners,especially,ones,new,Motorola,phones,Instead,lists,features,expects,put,together,'s,C++,Reference,vs,Learn,How,Program,C++,Days.,Maybe,Motorola,technical,writers,just,technical,3-,Drops,dings,Ferrari,probably,go,week-long,mourning,first,time,ding,phone,hoping,be,[,good,],cases,available,protect,V3,juggles,w/,keys,pocket,SIDE,NOTE,heard,Cingular,/,Lockline,is,not,insuring,phone,Cingular,sales,guy,was,hesitant,sell,phone,bought,insurance,EDGE,girlfriend,Motorola,v551,has,EDGE,Shame,shame,shame,Motorola,Bad,Motorola,Bad,bad,bad,Alas,'s,akin,buying,Ferrari,Modena,having,cheap,factory,stereo,system,paying,Acura,NSX,'s,only,Internal,display,colors,was,hyped,hear,colors,Motorola,specs,detective,footwork,is,colors,up,colors,MPEG-4,video,playback,Very,very,sneaky,mis-leading,indeed.Wishlist:1-,wished,was,PocketPC,smart,phone,version,phone,PocketPC,+,V3,form,factor,perfection.Regarding,multiple,numbers,name,review,set,phonebook,display,only,primary,numbers,by:1-,setting,primary,number,names,multiple,numbers,n't,have,do,name,only,has,number,2-,set,address,book,view,Primary,Contacts,Phonebook,Menu,Phonebook,Setup,View,3-,voila,only,primary,numbers,displayed.The,way,Motorola,has,implemented,is,not,very,intuitive,Nokia,implementation,refer,owner,manual,dis-like,found,Motorola,implementation,be,little,more,robust.UPDATE,'s,been,nearly,weeks,bought,phone,buyer,remorse
#
# chief,complaint,phone,is,Ringtone,selector,is,accessible,outside,phone,causes,be,changed,simply,handling,fiddling,pocket,been,numerous,times,i,missed,calls,was,inadverdantly,set,silent,just,being,pulled,pocket,rest,complaints,poor,confusing,Motorola,software,menu,structure,phone,does,quite,bit,rarely,i,find,access,features,even,months,ownership,i,owned,several,other,Motorola,phones,often,talking,buried,inscrutable,set,menu,i,trying,do,something,else,activate,find,number,phonebook,software,is,also,slow,unresponsive,compared,Nokia,Samsung,gives,lazy,inexact,feel,pluses,rubberized,finish,is,easy,grip,full,support,bluetooth,sucks,so,much,battery,power,becomes,borderline,useless,nice,large,well,lit,keys,crisp,screen.The,phone,has,overall,feeling,solidity,being,too,heavy,clumsy,feeling,gotten,more,drops,phone,other,i,never,used,cingular,i,n't,know,service,phone,Overall,i,like,phone,i,searching,something,else,frustrations
#
# did,not,work,day,got,them.The,right,earbud,never,had,sound.I,got,replacement,'s,same,situation.I,not,sure,'s,using,Nokia,E71x,n't,work,properly
#
# bought,members,family,theie,headsets,using,is,little,background,noise,headset,is,n't,bulky,others,hours,talk,time,has,been,connected,Motorola,Nokia,Samsung,cell,phones.I,had,faulty,was,quickly,resolved,Amazon,Other,products,perfectly
#
# was,first,clamshell,phone,aspect,phone,'s,seems,have,worse,reception,previous,phones,Nokia,bar,type,same,coverage,areas,biggest,issue,is,definitely,battery,NOT,heavy,cell,phone,user,so,just,leave,phone,car,gym,bag,not,worry,couple,days,phone,drain,hours,hours,MINIMAL,USAGE,n't,know,drains,so,quickly,seems,be,random,speeds,is,extremely,frustrating,Also,not,thrilled,intuitiveness,lack,thereof,menus,sure,have,become,familiar,time,n't,have,chance,phone,looking,return,mine,ASAP.CONS,POOR,Battery,LifeWorse,reception,previously,owned,phonesNot,comfortable,holdPROS,Looks,goodCompact
#
# owned,Treo,again,model,came,Initially,was,extremely,frustrated,phone,telephone,performance,lack,stability,Frequent,reboots,freezes,dropped,calls,made,difficult,appreciate,phone,ended,getting,rid,relying,separate,palm,cell,phone,time,PalmOne,has,released,firmware,updates,phone,operating,system,made,phone,very,stable,improvements,so,significant,actually,won,back,review,is,GSM,Treo,word,Carriers,only,GSM,abroad,frequently,limits,Cingular,Tmobile,used,found,Cingular,network,coverage,is,more,complete,especially,rural,areas,Tmobile,network,sounds,better,'s,tradeoff,Tmobile,drop,call,more,often,Cingular,say,more,often,coverage,is,about,equal,big,cities,major,highways,International,roaming,is,less,expensive,Tmobile,Cingular,has,few,hurdles,place,prevent,enabling,international,roaming,account,been,less,months,Verizon,Sprint,cellular,technology,is,US-only,therefore,good,using,phone,phone,pros,pocket,address,book,datebook,notes,e-mail,low-res,still,video,camera,very,nice,sms,threads,sms,exchanges,contact,web,browser,mp3,player,QWERTY,keyboard,makes,typing,much,faster,standard,phone,interface,is,unique,need,little,time,get,used,once,be,efficient,quick-dialing,keeping,daily,use,other,phone,Also,phone,is,quad-band,GSM,means,work,very,well,abroad,more,common,tri-band,GSM,phones,n't,perform,as,well,Remember,Treo,Smartphone,Verizon,Sprint,not,work,abroad,screen,Palm,version,is,brilliant,Windows,version,is,not,sharp,limitation,imposed,operating,system,Also,GSM,technology,uses,SIM,cards,means,simply,change,SIM,use,phone,network,phone,number,domestically,abroad,have,phone,locked,carrier,network,contract,commitment,is,complete,'s,something,sort,own,phone,cons,said,pocket,thing,belt,bulge,force,make,alterations,sport,jacket,Also,age,identity,theft,information,security,think,long,hard,about,just,much,information,is,there,Believe,phone,quickly,becomes,place,store,passwords,account,information,customer,information,etc,Consider,feel,restaurant,'s,stolen.Here,lesser,cons,be,worked,beauty,palm,phones,is,so,popular,other,people,had,problem,encounter,written,software,address,/,fix,/,work,issue,example,found,phone,volume,is,not,loud,enough,is,party,volume,software,fix,that,as,well,software,allows,use,phone,Bluetooth,modem,computer,software,is,freeware,is,shareware,is,purchase,key,is,so,many,forums,resources,Internet,search,find,answers,phone,allows,install,uninstall,as,much,ease,home,PC.Thoughts,newer,Treo,phones,now,costs,little,less,Treo,come,is,good,thing,n't,see,having,new,features,upgrade,Other,slightly,redesigned,appearance,interface,higher,resolution,camera,phone,features,basically,identical,Also,Summer,Treo,is,only,available,CDMA,networks,Treo,folks,staggered,release,GSM,CDMA,models,give,carriers,turn,exclusivity.Looking,future,is,speculation,next,generation,Treo,phone,be,GSM,be,thinner,lighter,antenna,be,internal,basically,more,resemble,blackberry,outside,much,sought,features,Treo,users,Maybe,upgrade,then.In,conclusion,only,stars,phone,product,was,n't,ready,market,released,'s,much,better,now,had,initially,released,current,product,have,given,stars,perspective,helps,decision.UPDATE,Jan,Treo750,windows,mobile,has,come,UK,Vodafone,here,USA,Treo680,Palm,OS,has,been,announced,Cingular,forums,internet,people,reported,new,addresses,many,wish-list,items,Treo,faithful,slighly,thinner,modest,few,millimeters,internal,antenna,better,keyboard,volume-too-low,issue,sort,resolved,better,mp3,player,pTunes,instead,Real,more,memory,improved,phone,interface,EDGE,instead,GPRS,double,data,speed,Unfortunately,camera,has,same,resolution,few,millimeters,meant,thinner,battery,owners,poor,battery,life,day,significantly,less,power,users,.As,Thanksgiving,vendor,pre-selling,Treo,was,sold,including,Amazon,tells,things,many,Treo,users,looking,upgrade,immediately,choice,not,necessity,result,market,be,flooded,inexpensive,used,Treo650s,doubt,merchants,inventory,probably,sell,inexpensively,enough,people,been,priced,smartphone,market,get,hands,one.Palm,says,is,targeted,day,person,not,p ...
#
# used,headset,Nokia,PC,works,great,switching,back,forth,easily,telling,PC,phone,connect,Light,crackling,occasion,is,active,area,not,terribly,noticeable,Sound,quality,is,great,indoors,great,thing,is,comfort,wear,day,long,even,'s,not,smallest,lightest,headset
#
# Simply,awesome,best,one,ever,had,sticking,one,motorola,nokia,samsung
#
# Ever,i,bought,headset,become,fan,comfortable,wear,whole,day,even,feeling,anythin,is,voice,is,crystal,clear,very,easy,use,pairs,perfectly,nokia,as,well,Dell,Laptop,i,VOIP,calls,mobile,phone,calls,Also,service,was,great,received,package,right,estimated,date,never,had,followup,anyone,Superb,Product
#
# bought,RAZR,v3,phone,July,go,7-Eleven,Speak,Out,Wireless,prepaid,service,phone,received,Amazon.com,was,made,Hong,Kong,market,came,outlet,plug,adapter,U.S.,customers,AC,adapter,is,universal,voltage,slim,paper,manual,is,English,phone,is,quadband,fully,unlocked,be,used,anywhere,world.I,really,RAZR,phone,'s,very,solid,voice,quality,is,excellent,Speak,Wireless,runs,AT,T,T-Mobile,networks,reception,quality,vary,RAZR,does,excellent,job,pulling,as,much,signal,possible,other,Moto,phones,brightness,screen,be,adjusted,ringer,type,volume,be,easily,changed,metallic,keypad,takes,little,getting,used,is,pretty,comfy,use.The,camera,is,only,VGA,takes,good-quality,pictures,'s,plenty,light,Video,capture,is,jerky,limited,seconds,'s,probably,weakest,feature,Bluetooth,linkup,Sony,Ericsson,works,fine,Battery,life,is,admirable,n't,use,phone,much,maybe,just,minutes,week,recharge,once,days,so.Because,owned,many,Moto,so,RAZR,interface,feels,familiar,understand,confuse,users,new,Moto,scene,Overall,n't,think,'s,harder,use,Sony,Nokia.What,really,impresses,is,build,quality,phone,Nowhere,find,thing,is,made,material,fit,finish,excellent,very,happy,inexpensive,purchase
#
# i,bought,replace,cingular,phone,works,well,package,came,europe,charger,cheap,plug,adapter,had,manuals,everything,seemed,legitimate,box,was,n't,sealed,product,was,manufactured,again,everything,works,nokia,UI,battery,time,is,okay,reception,seems,fine,n't,been,able,find,driver,vista,yet,so,n't,been,able,charge,usb.i,buy,unlocked,phone,again
#
# updated,Good,battery,life+,Very,comfortable,choice,ear,bud,tips,extras,Easy,use+,Minimal,bling,appeal,blue,light,is,not,obtrusive,First,unit,failed,charger,headset,buggy,only,weeks,use-,Jabra,Support,is,lackluster-,Ugly,shiny,mic,piece,photo,Amazon,is,not,accurate,see,customer,images,weeks,use,stopped,charging,AC,adapter,dropped,audio,connections,dialing,minutes,conversation,Replacement,unit,has,also,exhibited,less,Contacted,Jabra,charging,issue,required,headset,RMA,THEN,b,send,new,less,month,use,found,way,get,replacement,boomerang,purchase,local,chain,'tronics,plus,side,lasts,standby,few,days,vice,few,hours,Sony,BT,headset,does,fits,ear,comfortably,ear,very,easily,loop,is,soft,rubber,sharp,rigid,plastic,is,clamping,outer,ear,sound,is,not,quite,loud,enough,volume,controls,easy,find,touch,in-ear,speaker,only,blast,so,much,earbud,be,gently,pressed,form,seal,is,easier,hear,way,Sound,is,so-so,callers,told,n't,hear,ambient,sound,music,wind,cars,nearby,better,average,is,second,Jabra,product,'s,crapped,so,be,wary,always,owning,wired,headset,backup,particularly,business,important,personal,use,JULY,UPDATE,**I,now,used,years,give,much,better,review,unit,has,held,well,tip,broke,had,be,glued,back,still,holds,several,hours,charge,old,Sony,headset,now,lasts,minute,conversation,dies,shape,weight,ergonomic,fit,so,unobtrusive,had,companions,still,wearing,hanging,call,did,n't,shiny,bling,microphone,tip,now,softened,design,BT500,is,still,more,attractive,less,attention,getting,others,headset,work,new,car,has,HandsFreeLink,feature,unit,home,years,still,works,great,headset,reservation,Disclosure,Nokia,not,tested,other,phone,models
#
# always,have,use,lot,features,Razr,recommend,Positives,light,weight,small,size,speaker,phone,works,well,display,is,easy,see,voice,dial,is,accurate,is,great,conversation,piece,Negatives,Speakers,normal,speaker,not,clear,sounding,Nokia,IR,port,has,USB,port,not,software,use,even,charging,phone,battery,life,little,short,video,recording,time,way,too,short,difficult,find,name,address,book,lot,keystrokes
#
# person,said,review,phone,is,thin,is,too,bulky,handle,seems,flimsy,not,disagree,more,feels,extremly,sturdy,is,not,tiny,phone,is,very,thin,weighs,more,then,expect,n't,mind,feels,bit,more,well,made.I,had,version,Motorola,V557,had,well,year,now,got,free,gave,friend,needed,phone,badly,cingular,customer,was,wanting,new,phone,anyways,worked,well.I,got,Nokia,weeks,ago,say,is,good,deal,price,just,did,n't,like,returned,got,razr,spent,bit,more,razr,was,reasonable,razor,is,simple,phone,good,phone,comes,very,pretty,case,make,happy,time,has,good,quality,camera,'s,NOT,digital,camera,more,good,quality,cam,very,easy,read,dial,everything,is,so,clear,spaced,nicley.I,got,black,version,named,KIT,night,rider,car,reminds,dork,had,read,complaints,phone,did,n't,come,enough,stuff,well,'s,launch,price,point,say,was,overpriced,Now,has,come,down,is,good,deal,book.I,very,pleased,so,far,Pleased,enough,come,review,also,cool,accessories,get,including,vynle,sp,skins,color
#
# very,impressed,headset,set,was,simple,SE,K700i,phone,just,paired,devices,added,handsfree,mode,headset,is,light,extremely,comfortable,ear,Just,move,gel,earpiece,left,right,ear,additional,comfort,Conversely,move,gel,earpiece,right,left,ear,fits,so,well,ear,n't,have,need,use,ear,loop.The,sound,clarity,is,great,Everyone,says,very,well,just,needed,raise,volume,little,hear,everyone,perfectly,n't,hear,static,whatsoever,headset,wifi,networks,home.Plantronics,gives,lot,charging,options,SE,charging,adapter,snapped,bottom,little,pocket,case,use,charger,gadgets,headset,comes,Nokia,Samsung,Siemens,Sony,Ericcson,adapter,charging,headset,also,comes,own,charger,case,n't,own,phone,models,use,wall,outlet,tried,method,charging,works,fine,too.This,headset,also,comes,mobile,charger,case,AAA,battery,did,n't,try,method,charging,SE,car,charger,works,well,included,SE,adapter.Voice,dialing,works,fine,'s,important,mobile,professional,spends,lot,time,traveling,car.The,headset,does,beep,right,call,also,beeps,right,signals,name,call,n't,find,irritating,other,reviewer,mentioned,'s,just,headset,operates,let,emphasize,headset,works,great.It,is,best,bluetooth,headset,ever,owned
#
# previous,user,Logitech,Mobile,Freedom,headset,lost,dropping,movie,theatre,many,others,so,know,bluetooth,headset,be.First,impressions,liked,size,headset,spiffy,metal,case,store,included,trinklets,even,mirror,back,case,so,see,cool,headset,box,'s,easy,setup,Took,hrs,charge,headset.Pros,headset,is,light,small,well,designed,ear,gel,is,n't,intrusive,old,Jabras,say,'s,earphone,use,mp3s,'s,made,rubber,is,good,n't,slip,other,gels,default,does,n't,fit,small,set,ears,default,is,perfect,pairs,easily,LG,PM,Sprint,Phone,n't,notice,difference,old,Logitech,terms,sound,quality,meaning,quality,is,excellent,heard,heard,was,clear,static,get,static,'s,just,downfall,BT,technology,wi-fi,walls,microwave,interference,also,comes,different,charging,attachments,Motorola,Nokia,Siemens,Sony,Eriksson,also,use,power,adapter,works,well,pen/marker,sized,charger,put,n't,see,using,AAA,battery,option,charge,'s,great,be,able,charge,anywhere,need,be.Cons,Well,here,is,was,wind,guard,be,great,feature,have,'s,so,mobile,n't,be,better,use,outdoors,Foam,is,n't,that,expensive,add,Secondly,have,been,noise,reduction,feature,Trust,pick,everything,dishes,back,people,talking,stereo,blah,blah,Oh,well,Otherwise,'s,great,Other,price,is,biggest,con,got,here,J,R,had,Ridiculous,Even,is,high,BT,headset,days,hey,look,feel,fit.If,n't,care,obtrusiveness,get,Logitech,Mobile,Freedom,'s,cheaper,thing,was,different,is,Logitech,finishing,call,sometimes,disconnect,phone,BT,connection,was,annoying,wanted,make,call,right,away,plantronics,n't,have,issue,is,awesome
#
# Using,Nokia,N97,left,mount,side,covers,botton,right,mount,side,presses,camara,botton,installing,unlock,application,issue,ulock,botton,got,solved,solve,camara,problem,material,had,be,cut,out.Update,Works,great,iPhone,even,protective,leather,casing
#
# sony,ericsson,W600,reviewupdated,note,phone,has,been,sent,back,manufacturer,twice,now,problems,thinking,phone,more,i,say,software,is,buggy,lot,people,please,take,consideration,buying.i,bought,phone,early,december,oh-so-NOT-low,price,letstalk.com,i,was,only,about,months,two-year,contract,so,yes,i,paid,full,price,eek,past,i,owned,most,major,brands,phones,motorola,nokia,samsung,sony,ericsson,sharp,right,i,got,phone,i,was,happy,motorola,V551,owner,initially,i,had,wanted,sony,ericsson,W800,band,being,cingular,customer,i,was,n't,going,risk,it.in,short,i,phone,date,'s,best,phone,i,owned,i,n't,think,'s,i,paid,'s,really,fault,i,impatient,wanted,phone,reeeeeally,bad,did,n't,want,wait,dropped,price,ever,i,going,cover,few,major,components,phone,then,list,pros,cons,mine,is,cingular-branded,phone,so,keep,mind,i,certain,features.camera,i,had,few,camera,phones,one,i,preface,section,saying,others,said,'s,camera,PHONE,'s,not,going,have,quality,make,even,decent,print,IS,good,moments,thinking,i,wish,i,had,camera,right,now,last,phone,was,VGA,camera,i,thought,getting,phone,MP,camera,be,noticable,difference,is,n't,really,however,cameras,phones,such,relative,subject,once,person,think,pic,looks,good,others,looks,total,doodie,i,urge,look,samples,pics,phone,has,taken,judge,i,was,n't,too,impressed,'s,not,i,bought,phone,camera,has,lot,neat,little,options,special,effects,white,balance,shoot,mode,night,mode,self-timer,'s,kinda,lost,pictures,n't,great,be,noted,camera,phone,sony,ericsson,S710a,phone,very,similar,W600,S710a,has,CCD,sensor,results,better,pics,phone,also,take,little,grainy,video,clips,moving,bluetooth,does,n't,seem,be,easy,use,motorola,i,learning,do,here,was,was,cool,was,transferring,ringtones,friend,SE,T616,mine,free,ringtones,i,n't,have,bluetooth,PCs,i,not,comment,connectivity,relation,i,just,option,is,there.walkman,holy,crap,'s,MP3,player,phone,walkman,is,pretty,easy,use,so,is,software,transfer,songs,phone,took,minutes,transfer,songs,'s,not,incredibly,fast,'s,cool,app,nonetheless,phone,hold,60-70,songs,ripping,other,bitrates,is,possible,allowing,more/less,songs,be,stored,phone,depending,other,stuff,phone,pics,vids,sound,is,pretty,damn,good,listen,MP3s,speakers,headphones,i,was,very,impressed,phone,does,NOT,have,plug,comes,adapter,is,well,i,even,plugged,phone,car,cassette,adapter,played,MP3s,car,stereo,speakers,MP3s,also,be,used,ringtones,all-in-all,complaints,here,well,limit.radio,nice,little,feature,have,headset,plugged,listen,radio,acts,antenna,'s,plugged,send,sound,come,speakers,radio,is,easy,use,channels,easy,store,radio,sounds,good,radio,as,well,MP3,player,pause,call,resume,done,also,use,radio,MP3,player,doing,other,things,phone,headphones,sound,awesome.games,phone,came,games,asphalt3D,blockbreaker,bruwnswick,billiards,jewel,quest,name,tune,tetris,extreme,air,snowboarding,games,locked,only,play,minute,then,prompted,purchase,6-,roughly,total,rip,thanks,cingular.ringtones,again,thanks,cingular,only,ringtones,phone,pretty,crappy,free,ones,place,so,n't,go,spending,inheritance,buying,cingular,i,grab,SE,phone,bluetooth,is,little,app,including,phone,called,musicDJ,actually,make,own,ringtones,kinda,cool,i,made,few,so,far,n't,bad,well,mom,said,sounded,horrible,does,know,syncing,phone,syncs,contacts,tasks,notes,calendar,kinds,programs,PC,i,got,phone,sync,outlook,now,means,i,sell,PDA,SE,PC,suite,works,pretty,well,transferring,files,is,easy,however,seems,now,again,i,connected,USB,reboots,phone,n't,know,'s,i,n't,think,harm,is,being,done.the,phone,feels,pretty,solid,hand,weight-wise,i,never,owned,slider/swivel,phone,life,'s,not,most,convenient,flip,open,'s,not,bad,actually,place,receive,calls,phone,swivelled,shut,too,seems,SE,did,n't,leave,anything,phone,memory,slot,i,thought,everything,phone,radio,little,flash,light,dedicated,key,lock,button,infrared,calendar,music/video/picture,DJ,stopwatch,timer,tasks,notes,list,goes,phone,styling,ie,orange,cover,is,n't,everyone,i,phone,did,come,cover,navy,blue,'s,styling,shape,is,great,i,orange,backlit,keypad,'s,d ...
#
# picked,Amazon,months,thinking,buying,needs,small,not,phone,much,car,lot,also,not,overly,picky,works,happy.The,Motorola,is,small,long,yet,seems,pick,voice,quite,well,sound,quality,calls,thus,far,has,been,good,Better,Nokia,phone,earpiece,is,adjustable,fits,ear,very,well.The,packaging,item,was,kind,weird,Plastic,baggie,charger,headset,directions,expected,box,unit,charged,fully,about,hours,Nokia,phone,picked,just,fine,once,enabled,bluetooth,find,it.All,things,considered,price,paid,does,happy,purchase,true,test,be,item,durability,battery,life,only,time,tell
#
# tried,few,BT,headsets,came,down,Nokia,BH-800,Jabra,JX10,units,good,audio,quality,also,liked,units,small,Thus,n't,look,way,Star,Trek,convention,wearing,liked,JX10,design,BH-800,had,trouble,understanding,voice,commands,Microsoft,Voice,Command,XV6700,PocketPC,phone,had,speak,JX10,very,slow,clearly,achieve,only,%,success,rate,understanding,commands,first,try,subsequent,tries,BH-800,understands,commands,closer,%,first,try,%,second,try.The,JX10,was,comfortable,ear,earloop,never,came,close,falling,out-,passed,head,tilt,test,bend,test,earloop,however,barely,hear,unit,earloop,prevents,unit,coming,close,enough,ear.Pros:1,Good,audio,quality,People,clearly,hear,clearly,hear,them.2,'s,small,'s,less,geeky,headsets.3,Nice,look,button,layout.4,Charge,cradle,USB,charging,is,nice,bonus.Cons:1,had,remove,ear,loop,get,unit,close,enough,ear,hear,it.2,felt,break,unit,connecting,disconnecting,cradle.3,Did,not,work,well,Microsoft,Voice,Command,was,show,stopper,picked,Nokia,BH-800,instead
#
# ...
#
# Now,Spring,is,rolling,was,glad,get,opportunity,review,phone/GPS,mount,received,review,sample.The,handlebar,mount,is,pretty,standard,locks,oval,thumb,screw,phone,grip,is,giant,plastic,clip,silicone,pads,clip,opens,real,wide,grip,anything,up,inches,old,Samsung,usually,biking,Nokia,gripped,securely,n't,fall,phone,clip,is,connected,handlebar,mount,plastic,ball,joint.All,mounts,grips,secure,mounted,properly,Most,importantly,silicone,grip,pads,phone,is,pretty,secure,ball,joint,means,rotate,phone,angle,joints,mount,configure,phone,face,many,ways,Also,clip,is,pretty,generic,clip,wallet,rolled,towel,other,small,item,it.I,caution,due,plastic,construction,screws,not,be,tightened,mount,be,checked,cracks,time,current,price,due,utility,item,strongly,recommend
#
# Eachine,Xpower,X3,mAh,power,bank,has,very,slim,attractive,design,soft-touch,plastic,shell,mdash,really,way,feels,hand.The,color-contrasting,cables,sides,get,lost,easy,remove,separate,cable,is,also,included,mini,USB,30-pin,Apple,Nokia,power,bank,was,delivered,fully,charged,recharges,overnight,powered,USB,port,wall,auto,charger,has,four-LED,capacity,display,%,increments,A,ports,smart,circuitry.The,mAh,battery,provide,least,mAh,usable,capacity,using,conservative,%,efficiency,factor,recharge,iPhone,Kindle,Paperwhite,least,times,give,big,boost,small,tablet.Don,forget,press,button,initiate,device,charging.Eachines,provided,sample,testing,unbiased,review
#
# battery,pack,is,almost,identical,size,shape,iPhone5,has,silk,black,finish,is,somewhat,rubbery,blue,LED,lights,much,juice,is,left,battery,pack,be,recharged,%,mAh,Theoretically,be,able,fully,charge,iPhone5,times.Outputs,Total,outputs,built-in,microUSB,cable,USB,USB,out.Compatibility,comes,own,built-in,input,output,cord,only,need,microUSB,tip,n't,have,bring,extra,cable,covered,also,includes,separate,microUSB,cable,connector,tips,30-pin,Apple,devices,miniUSB,Nokia.Other,lousy,packaging,is,nice,looking,power,bank,is,very,portable,Size,shape,is,just,perfect,throw,purse,emergency,power,it.A,sample,product,was,sent,review,purposes
#
# Eachine,Ultra-slim,X3,charger,makes,happy,'s,so,light,compact,size,cell,phone,tuck,pocket,emergency,charges,has,smooth,sure-grip,surface,built,USB,Micro,B,plugs,so,never,carry,extra,cord,charging,also,comes,extra,charging,tips,Mini,B,Apple,Nokia.It,does,n't,have,power,bigger,chargers,'s,good,maybe,short,charges,phone,charges,recharges,quickly,color,case,is,quite,wonderful,too
#
# is,big,capacity,mAh,power,bank,USB,charging,slots,slot,rated,cell,phones,other,small,electronics,other,tablets,iPads,also,incorporates,LED,lamp,use,emergency,flashlight.The,cool,thing,power,pack,is,LCD,panel,gives,exactly,much,juice,is,left,percentage,also,gives,slot,is,being,used,turn,flashlight,quickly,press,button,times,same,turn,off.Included,is,microUSB,cable,several,adapter,tips,Also,included,30-pin,Apple,connector,miniUSB,Nokia,adapter,short,manual,Made,China.A,sample,product,was,sent,review,purposes
#
# had,ton,Power,Banks,pass,way,last,months,reality,is,one,has,crossed,path,has,been,able,charge,Lumia,old,Blackberry,iPhone,problem,had,varying,capacities,so,on.The,Eachine,is,definitely,nicer,ones,received,helps,make,stand,is,fact,very,few,others,had,is,nice,LCD,display,show,actual,percentage,battery,power,left,Power,Bank,Usually,just,get,few,lights,indicate,never,really,knowing,just,much,final,light,really,is,left,recharge,now,more,cycle,more,guessing,here.The,other,nice,thing,is,price,mAh,external,battery,LCD,capability,Definitely,sets,others,had,still,have.Also,making,stand,is,included,tips,None,others,used,price,range,offered,USB,Micro,USB,mini,plug,adapter,be,clear,make,micro,USB,cable,plug,mini-USB,chargeable,device,also,includes,Micro,USB,older,style,iOS,charger,lightning,included,is,also,Nokia,adapter,older,Nokia,phones,n't,test,out,Still,usually,just,get,cable,charge,Power,Bank.The,capacity,given,general,efficiency,recharging,net,roughly,full,charges,iPhone,Lumia,get,4-5,recharges,is,normal,Power,Banks,Physics,be,darned,Also,nice,is,charge,devices,once,is,n't,recommended,charge,devices,charge,Power,Bank,same,time,affect,negatively,life,expectancy,Power,Bank,comes,portability,one,is,n't,too,bad,mAh,worth,batteries,means,'s,kinda,heavy,not,overly,so,easily,fit,back,pocket,hand,bag,emergency,charge,needed.It,also,includes,flashlight,'s,bright,enough,see,dark,'s,not,great.Overall,is,great,power,bank,good,features,sets,pack.Highly,recommended.I,received,free,sample,review,purposes,manufacturer
#
# is,rather,big,mAh,capacity,power,pack,compact,form,is,very,plain,clean,looking,making,nice,companion,son,white,iPad,mini,LED,flashlight,be,turned,turned,pressing,button,twice,backlit,LCD,panel,is,bright,gives,exact,battery,level,remaining,charge,devices,time,USB,slot,tablets,slot,cellphones,smaller,electronics,MP3,player,etc.Accessories,comes,microUSB,cable,connector,tips,30-pin,connector,older,Apple,devices,miniUSB,Nokia,8-pin,Lightning,tip,is,included,same,microUSB,cable,charge,battery,pack,as,well,charging,devices,connector,tips.Cons,only,gripe,is,poor,packaging,have,been,nice,thing,wrap,present,has,better,packaging.I,rating,stars,features,capacity,minimalistic,look,affordable,price,time,review,.A,sample,product,was,sent,review,purposes
#
# fantastically,impressed,chargers,received,Eachine,X2,is,everything,hope,sturdy,all-around,charging,device,'s,bit,bigger,heavier,X4,'s,miles,ahead,terms,power,'s,charged,phone,dozen,times,Kindle,Fire,least,twice,full,charge,charging,time,tablet,is,n't,nearly,as,fast,direct,connection,A2,connector,'s,fast,enough,make,happy,is,charger,take,trip.The,X2,other,Eachine,chargers,tried,comes,USB,Micro,B,cord,extra,connector,tips,Mini,B,Apple,is,Nokia,connector,has,bright,easy-to-read,LED,display,shows,remaining,charge,output,plugged,'s,latter,is,charge,Kindle,Fire,display,is,activated,device,button,Press,hold,turns,Press,twice,turns,bright,LED,flashlight,located,just,input,turns,flashlight,back,off.Clearly,lot,thought,has,gone,Eachine,chargers,well-designed,versatile,X2,is,real,workhorse,group,Very,impressive
#
# Eachine,is,intents,purposes,exactly,same,Eachine,battery,more,powerful,only,few,bucks,more.Both,several,selling,points,bright,LCD,backlit,screen,displaying,current,battery,level,status,USB,outputs,most,importantly,internal,power,regulating,chip,prevents,overcharging,overloading,short,circuits,side,flashlight,function,is,bright,enough,spotlight,illumination,dark,environments.The,unit,weighed,ounces,has,heft,Not,really,something,slip,pocket,certainly,light,enough,backpack,traveling,rectangular,shape,also,fit,nicely,large,purses,uploaded,photo,pack,next,PSP,get,relative,sense,size.The,packaging,instructions,specifically,state,is,compatible,Various,lighting,Apple,Products,original,Apple,Lightning,USB,cable,as,well,specific,pin,adaptor,provided,iPhone,HTC,Phones,Samsung,Phones,Blackberry,Motorola,Nokia,comes,specific,DC2.0,connector,LG,Sony,Google,Nexus,Nexus,Amazon,Kindle,Fire,HD,DX,other,kindles,others,such,Nook,Tablet,Portable,WiFi,PSP,NOT,PS,Vita,not,listed,instructions,on-site,description,does,state,power,bank,is,NOT,COMPATIBLE,iPod,Nano,Samsung,Asus,tablets,few,other,sundry,GPS/Bluetooth,devices,Which,is,unfortunate,Samsung,Tab,tried,does,not,work,reliably,Tab,However,not,hit,does,specifically,state,is,n't,supported,also,tried,iPod,Nano,did,charge,full,yet,LCD,screen,did,not,register,discharge,rate,take,note,few,categories,does,n't,support,apparently,it.Now,reference,particular,PSP,power,bank,does,not,come,requisite,adapter,USB,charging,cables,PSP,available,here,Amazon,work,power,bank,bought,aData,Power,USB,Cable,Sony,PSPand,used,battery,pack,charm,even,playing,games,video,pack,charged,PSP,was,completely,dead,full,hour,only,%,'s,juice,Now,play,power,hungry,Final,Fantasy,games,impunity,also,tested,power,bank,Portable,Wi-Fi,Verizon,Jetpack,older,Kindle,Keyboard,were,recharged,timely,manner,internal,chip,automatically,stopping,power,output,were,intents,purposes,still,shame,Samsung,Tab,not,being,supported,yet,is,excellent,battery,honestly,model,few,dollars,more,get,Clint,Eastwood,powerhouse,n't,resist,pun,P,received,complimentary,review,product,aim,hopefully,elucidating,features,drawbacks,help,ultimately,decide,fits,needs,budget,best,questions,feel,free,ask,be,more,happy,answer,even,YouTube,video,demonstration,possible,particular,aspect,like,clarification
#
# ZEETRON,selected,clever,name,portable,USB,charger,is,bulky,key,chain,contents,rubber,Hippo,services,compact,serves,connector,charging,USB,end,devices,using,USB,headed,Lightning,USB,iPhone,iPod,devices,micro,USB,Samsung,Nokia,HTC,Blackberry,LG,devices,only,item,missing,kit,is,charging,source,course,power,banks,wall,chargers,car,chargers,floating,around,everyone,has,plenty,sources,power,just,not,enough,readily,available,connectors,little,gadget,helps,problem,Take,anywhere,charge,multiple,devices,car,trip,Works,well,is,clever,boot,Grady,Harp,June
#
# been,using,car,charger,had,been,purchased,use,Kindle,also,works,Nokia,phone,only,had,USB,port,found,charger,was,tad,loose,cigarette,lighter,think,was,charging,something,sometimes,find,nothing,had,happened,had,come,just,enough,not,be,contact.This,is,solid,fit,power,indicator,light,comes,let,know,'s,seated,properly,matter,fact,got,put,little,effort,pulling,was,provided,sample,review,so,happy,got,try,port,is,larger,items,tablets,middle,port,small,devices,third,port,things,MP3,players,not,so,sure,n't,plug,phone,MP3,player,slots,phone,does,give,error,message,recharge,plugged,tablet,port.It,really,nice,have,ability,charge,more,device,time
#
# is,nice,mount,using,Nokia,has,be,able,handle,size,weight,large,smartphone.It,does,just,that.Place,Nokia,mount,mounted,windshield,full,size,pickup,Went,long,road,trip,see,fireworks.It,stayed,put,windshield,kept,expecting,fall,windshield,did,not,also,expected,mount,give,way,slowly,move,downwards,.but,did,not.The,final,BIG,selling,feature,is,phone,mount,little,pressure,side,arms,place,.so,spilled,phone.So,based,needs,expectations,mount,well,pay,reasonable,price,get,reasonably,constructed,mount.free,sample,provided
#
# HTC,phones,last,year,One,m7,year,m8,NOT,affiliated,HTC,compensated,way,just,feel,competition,underdog,companies,crucial,essential,healthy,free,market,economy,ultimately,consumers,had,iPhones,Samsung,Galaxy,S3/S4,Note,several,Nokia,n95-97,n84/85,several,lesser,phones,Sony/Sony-Ericsson,Xperia,phones,years,loved,most,healthy,positive,technological,evolution,small,struggling,companies,HTC,succeed,Apple,Samsung,become,duopolies,be,dark,future,indeed,Pick,HTC,One,M7,M8,Samsung,Galaxy,phones,compare,quality,craftsmanship,tell,'s,Samsung,not,HTC,more,successful,phones,'s,MONEY,marketing,bigger,guy,trying,squeeze,smaller,guy,'s,NOT,healthy,free,market,economy,be.Now,is,way,let,get,nitty,gritty,is,direct,comparisons,iPhone,Samsung,Galaxy,S4/S5,Note,mainly,last,HTC,One,M7,mainly,updating,keypoints,m7,review,.Keep,mind,is,is,EXCLUSIVE,Sprint,version,is,different,includes,Harmon,Kardon,audio,hardware,tweaks,called,Clari-Fi,details,later,review,pair,Harman/Kardon,AE-S,In-ear,Headphones,retails,separately.The,Good:1,SCREEN,was,such,better,screen,phone,not,yet,seen,iPhone,is,lauded,excellent,screen,current,resolution,trails,One,screen,far,Everything,just,POPS,Even,direct,sunlight,everything,is,CLEAR,BRIGHT,really,loved,HTC,One,M7,screen,once,again,HTC,has,outdone,given,true,masterpiece,form,main,difference,M8,M7,is,color,reproduction,M8,is,better,more,true-to-life,is,BEST,screen,planet,right,now,WOW,DESIGN/HARDWARE,Once,again,new,continues,HTC,tradition,making,really,high-quality,phones,high-class,material,craftsmanship,version,has,more,matted-brushed,aluminum,finish,glossier,M7,feels,THICK,TOUGH,n't,have,worry,carrying,case-less,drops,is,whole,other,issue,not,be,worried,phone,nicking,scraping,iPhone,Personally,not,have,flair,Sony,Nokia,phone,past,totality,One,has,best,combination,design,craftsmanship,oozes,style,sophistication,plastic-y,feel,Samsung,Galaxy,S4/S5,is,real,looker,DUAL,FRONT-FACING,SPEAKERS,been,desensitized,modern,smartphones,nowadays,crappy,tinny,mono,speaker,days,Nokia,n95,n84,stereo,speakers,happened,phones,agreed,mono/solo,speaker,smartphones,thereafter,FINALLY,someone,has,senses,come,back,reality,thank,HTC,Trust,ears,thank,realize,phones,have,been,made,Especially,ringtones/alerts,were,specifically,created,phone,sound,is,loud,immersive,expansive,POPs,ears,'s,simply,re-revolution,Compared,M7,M8,loses,Beats,audio,engineering,actually,sounds,louder,M7,has,really,high-quality,speakers,well,was,known,being,too,soft,certain,scenarios,new,moniker,is,just,BoomSound,*,exclusive,Sprint,version,includes,audio,hardware,tweaks,Harmon,Kardon,helps,make,audio,even,better,Let,explain,as,concisely,possible,works,days,CD,music,track,was,50-100mb,sound,was,not,so,compromised,advent,mp3s,size,were,shrunk,down,5-10mb,song,sound,was,still,good,tell,something,was,missing,get,size,audio,was,compressed,so,parts,edges,highs,lows,chopped,still,decent,sound,just,not,full,high,fidelity,CD,DVD-caliber,files,Clari-Fi,tries,ameliorate,filling,chopped,portions,create,richer,fuller,sound,reality,notice,better,sound,certain,types,mp3,compressed,music,ones,heavily,compressed,such,kbps,bit,rates,opposed,something,fuller,higher,notifications/ring,tones,Internet,audio,not,notice,so,much,Nonetheless,is,welcome,upgrade.Secondly,free,pair,Harman/Kardon,AE-S,In-ear,Headphones,selling,currently,really,good,earbuds,far,much,much,better,anything,get,included,standard,phones,read,more,[,harmankardon.com/estore/hk/us/products/AE/HARKAR-AE_HK_US,],.4,THE,CAMERA,n't,use,phone,camera,make,prints,photos,dedicated,cameras,So,paramount,function,phone,cameras,is,convenience/accessibility,has,be,able,capture,quickly,clearly,decent,enough,quality,post,online,Therefore,size,One,camera,does,not,bother,cares,camera,is,n't,THE,BEST,phone,camera,ever,is,not,is,GREAT,low-light,shooter,'s,more,important,pixel,count,sensors,camera,bigger,other,phone,cameras,therefore,capture,lot,more,light,laymen,terms,give,better,photos,more,situations,other,phone,cameras,Also,touch,spot,focus,is,almos ...
#
# eBOOT,pays,attention,needs,customers,most,people,portable,power,bank,several,versions,customer,choose,power,bank,most,adaptabe,needs.This,small,very,powerful,resource,charging,quickly,capacity,protective,features,needed,built,protection,overcharge,overvoltage,overcurrent,short,circuit,battery,is,reliable,Samsung,Li-ion,charging,power,cord,USB,bank,widespread,adaptabiliy,is,excellent,rapidly,charges,Android,Tablets,Phones,iPhone,iPad,Air,Mini,Samsung,Galaxy,S4,S3,S2,Note,Kindle,Fire,HD,HDX,Google,Nexus,Motorola,Droid,Razr,Maxx,Moto,X,HTC,X,V,S,LG,G2,Nokia,Lumia,PS,GoPro,Bluetooth,Speakers,Headsets,External,Battery,Packs,Power,Bank,Other,USB,Charging,Electronic,Battery,n't,think,left,anything.Stylish,small,enough,fit,pocket,purse,still,be,unnoticed,is,terrific,unit,price,is,hard,beat,Great,gifts,Grady,Harp,July
#
# useful,emergency,power,backup,cell,phone,wife,is,using,emergency,backup,Nokia,Kept,purse,provides,backup,is,work,plug,phone,continues,make,rounds,mobile,work,life,not,just,sit,plug,outlet.I,received,free

# %% [markdown]
# <h3>Exercise - Optional</h3><br />
# Use the Name Entity Recognition in NLTK to recognise name entities in the extracted keywords. Add another record called Entities consists of these objects.

# %%
from nltk import word_tokenize, pos_tag, ne_chunk
from nltk import Tree
from pymongo import MongoClient
import re

def get_chunks(text, label):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree and subtree.label() == label:
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk

db = ""
try:
    connection = MongoClient("mongodb://localhost:27017")  # Connection String
    db = connection.amazon
except:
    print("Something went wrong!")

regx = re.compile("Nokia", re.IGNORECASE)
cursor = db.reviews.find({"reviewText": regx}, {"reviewText": 1, "keywords":1})

for e in cursor:
    GPEs = get_chunks(e['reviewText'], 'GPE')
    if len(GPEs) > 0:
        print(GPEs)
        db.reviews.update({"_id": e['_id']}, {"$set": {"GPEs": GPEs}})
# Out:
# ['Verizon', 'Ericsson', 'Nokia']
# ['Europe']
# C:\Users\farha\Anaconda3\lib\site-packages\ipykernel_launcher.py:39: DeprecationWarning: update is deprecated. Use replace_one, update_one or update_many instead.
# ['World', 'Camera', 'Video', 'Speaker', 'Calendar', 'New Zealand', 'Australia', 'Cingular', 'New Zealand Australia', 'Symbian', 'Java']
# ['Nokia']
# ['Moto', 'Activesync']
# ['Siemens', 'Nokia']
# ['Outlook']
# ['Got', 'Jabra']
# ['Nokia', 'Palm', 'English', 'Palm Palms']
# ['China']
# ['California']
# ['Nextel', 'Nextel Nextel', 'Sony', 'Nokia']
# ['Moto', 'Amazon']
# ['Sexy', 'Motorola', 'Program', 'Phonebook Menu', 'View']
# ['Motorola', 'Nokia']
# ['Sprint', 'Verizon', 'Sprint Palm', 'Treo750', 'Treo680', 'Real', 'Thanksgiving', 'Amazon', 'Palm', 'Symbian']
# ['Simply']
# ['Superb']
# ['Hong Kong', 'U.S.', 'English', 'T']
# ['First', 'Amazon']
# ['Nokia', 'Siemens']
# ['Nokia', 'Siemens']
# ['W600']
# ['Great', 'Bluetooth', 'Windows', 'Linux', 'Nokia']
# ['PalmOne', 'New York', 'Palm', 'Tri-Band', 'Motorola']
# ['Nokia']
# ['Nokias']
# ['Kuwaitthe']
# ['Bought']
# ['Samsung', 'Good', 'Great']
# ['Nokia']
# ['Great']
# ['Phone', 'Amazon']
# ['Plantronics']
# ['Belkin', 'Sprint', 'Sony']
# ['Excelente']
# ['China']
# ['Reliable']
# ['Up']
# ['Nokia']
# ['T', 'Europe', 'T Europe', 'Indians', 'Chinese']
# ['China']
# ['Great']
# ['Sim', 'Long', 'Symbian', 'Video']
# ['Someone']
# ['North', 'Antonline']
# ['Got']
# ['Product']
# ['Amazon']
# ['Symbian']
# ['Great']
# ['Great']
# ['Nokia']
# ['Great']
# ['Product']
# ['H710', 'H700']
# ['U.S', 'Warranty', 'Copper']
# ['Amazon', 'Nokias']
# ['Nokias']
# ['Nokia']
# ['Nokia']
# ['New', 'New Capacity']
# ['North']
# ['Nokia']
# ['Beware', 'Mbps', 'Smartphoneware', 'Nokia', 'T', 'T Service', 'T European', 'Asian', 'T Rogers', 'North America', 'North America North America', 'T Nokia', 'Japan', 'Infrared', 'Service', 'T N95', 'Symbian', 'T U.S.', 'N95', 'QVGA', 'Symbian U.S.', 'T Barcelona', 'February', 'Symbian U.S. Symbian', 'North']
# ['Simple', 'place.Range']
# ['Nokia']
# ['Nokia']
# ['Blueant', 'Jawbone']
# ['Nokias', 'Samsung']
# ['Amazon', 'Nokia']
# ['T']
# ['Nokia']
# ['Europe']
# ['Nokia', 'Google', 'Skype', 'Facebook']
# ['Lowrance']
# ['Nokia']
# ['T']
# ['Bought', 'Long']
# ['Update', 'Nokia', 'Excel', 'Nokia Review', 'Amazon', 'Omnia', 'Finnish', 'American', 'Excel European', 'European']
# ['Calendar', 'Google', 'Nokia']
# ['Africa', 'Amazon']
# ['Nokia', 'T']
# ['Nokia', 'Nokia Nokia', 'Google', 'Symbian', 'Google Silent', 'Symbian Turkish']
# ['Qwerty', 'E71', 'Nokia']
# ['Symbian', 'T', 'Nokia', 'Layouts']
# ['Nokia']
# ['Bluetooth', 'Sony', 'Nokia']
# ['Bluetooth']
# ['T', 'T Nokia', 'Power', 'Video']
# ['T', 'Demand', 'Nokia', 'T T']
# ['T', 'Playback']
# ['T', 'Sprint', 'Nokia', 'Symbian', 'Iphone', 'T Chinese', 'Nokia Iphone']
# ['Swiss']
# ['Reader', 'Warranty', 'T', 'T Qwerty', 'Helio', 'T Helio', 'Landline', 'Denon', 'T Euro']
# ['Drafts', 'T', 'Normal', 'Meeting', 'Offline', 'Portrait', 'Sports']
# ['Nokia', 'Apple']
# ['Symbian']
# ['T', 'Tilt', 'Fitaly', 'T Wifi', 'T Symbian', 'Symbian', 'N96', 'Symbian Camera', 'Nokia']
# ['T', 'T New', 'Great', 'Hancock', 'Applications']
# ['Nokia', 'North', 'North America', 'Japan', 'South Korea', 'U.S.', 'T', 'T T', 'T Sprint', 'Alltel']
# ['T', 'United States', 'Turn', 'T Again']
# ['Cheap', 'Blackdash', 'Amazon']
# ['Nokia', 'Symbian']
# ['Nokias']
# ['Amazon', 'Jabra', 'Good']
# ['Jabra']
# ['Easy', 'Google', 'Nokia']
# ['Apple', 'Camera', 'Multimedia', 'U.S.']
# ['U.S.', 'Safari', 'Multimedia', 'American', 'Nokia', 'Xperia', 'Windows']
# ['Nokia']
# ['Nokia', 'China', 'Finland', 'Banks', 'Me', 'Go', 'Free', 'Poker']
# ['Singapore', 'N95', 'Amazon', 'N96', 'North', 'North America', 'American', 'T', 'American Japan', 'Handhelds', 'American T', 'North American', 'N95 JBenchmark', 'N85']
# ['Samsumg', 'V300']
# ['Google', 'Nokia', 'T', 'Camera', 'T Calendar']
# ['T']
# ['T', 'China', 'Great']
# ['T']
# ['Google']
# ['Flash', 'Jabber', 'Facebook', 'Symbian', 'Symbian Nokia', 'T']
# ['Video', 'Quickfire', 'Nokia', 'Symbian']
# ['Nokia', 'Europe']
# ['Kuwait']
# ['T', 'Amazon', 'Demand', 'Nokia', 'U.S.', 'Iphone', 'U.S. Symbian']
# ['Phone']
# ['Android', 'Symbian', 'Nokia']
# ['Nokia', 'V21', 'U.S.']
# ['European', 'Chicago', 'Iphone']
# ['T', 'Bluetooth', 'Portrait', 'Windows', 'European']
# ['Amazon', 'Nokia', 'Wifi']
# ['Amazon']
# ['Nokia']
# ['Nokia']
# ['Nokia']
# ['Yahoo', 'Nokia', 'Iphone']
# ['Nokias']
# ['Sprint', 'Finland']
# ['Facebook', 'Mexico', 'Nokia']
# ['E71', 'Symbian OS', 'Camera', 'Symbian', 'Bluetooth']
# ['T', 'T T']
# ['Mac']
# ['Nokia']
# ['Plantronics', 'Sony']
# ['Symbian']
# ['T', 'Applications', 'Options', 'Setup', 'Unlock', 'Symbian']
# ['Nokia', 'Nokia Nokia']
# ['Wonderful', 'Home']
# ['Nokia', 'Tabletsline', 'Nokia Nokia', 'Switch', 'Flash', 'U.S.', 'T', 'Japan', 'Europe', 'T T', 'T T T', 'T T Brodit']
# ['Pioneer', 'Honda', 'Windows', 'Nokia', 'US', 'Amazon', 'Symbian', 'Nokia N85', 'Mac', 'N97', 'Java', 'Windows Nokia', 'Browse', 'Bluetooth', 'N85']
# ['Warranty']
# ['Palm']
# ['Nokia']
# ['Nokia']
# ['OtterBox', 'Amazon', 'Nokia']
# ['Palm', 'T', 'Verizon']
# ['Vista', 'Tenqa']
# ['Good']
# ['Bluetooth', 'Baltimore', 'Palm', 'Palm Nokia']
# ['Nokia']
# ['Motorola']
# ['Nokias']
# ['D', 'Nokia', 'Palm']
# ['Series', 'Series Series']
# ['Nokia']
# ['Nokia']
# ['Nokia', 'Great']
# ['Nokia']
# ['Ok', 'Nokia']
# ['Kamera']
# ['Nokia', 'Google', 'Debian']
# ['Symbian', 'Again', 'Symbian Blackberrys', 'Europe', 'Palm']
# ['Great', 'N900', 'Flash', 'Symbian']
# ['Android']
# ['Symbian', 'Maemo', 'Symbian Maemo', 'T', 'Nokia']
# ['Long', 'Nokia', 'Nokia Nokia', 'N900', 'Harmattan', 'Fremantle', 'N900 Harmattan']
# ['Symbian', 'T', 'T T']
# ['N900', 'Nokia']
# ['C6', 'N900', 'Symbian', 'N900 California', 'N900 N900']
# ['Camera', 'T']
# ['Octave']
# ['Nokia', 'Apple', 'Chromium', 'Chrome', 'Maemo', 'PAL']
# ['Zimbra']
# ['Im']
# ['Maemo']
# ['U.S']
# ['Nokia', 'Nokia China', 'T']
# ['Warranty', 'Warranty Chinese', 'Amazon', 'Amazon Warranty', 'Touchscreen', 'Black', 'Nokia', 'Amazon Calendar']
# ['Symbian', 'Symbian Symbian', 'Ovi', 'Ovi Ovi', 'Nokia', 'CHINA']
# ['Apple', 'Ctrl', 'Camera', 'Multimedia', 'Symbian', 'U.S.', 'Calendar']
# ['Tilt2', 'Magellan', 'E72', 'Nokias', 'Indoor', 'HTML', 'Micro']
# ['Got', 'Nokia', 'Europe']
# ['ViaTalk.com', 'Walking', 'Indoor']
# ['Nokia']
# ['Skyfire', 'Safari']
# ['Nokia']
# ['Amazon']
# ['Great']
# ['Postscript', 'T', 'Google', 'T Sprint', 'American', 'American North American', 'Asia', 'United States', 'United States Europe', 'Orange', 'Fredericksburg', 'US', 'Nokia', 'Nokia Outlook']
# ['Kindle', 'T']
# ['T']
# ['Symbian']
# ['C']
# ['Android', 'Symbian', 'Nokia']
# ['Xperia', 'Facebook']
# ['Amazon', 'Nokia', 'Amazon Call', 'Nokia T']
# ['Warranty', 'Blackberry', 'Nokia']
# ['Great']
# ['Long']
# ['Velcro']
# ['Ok']
# ['Cell']
# ['Thank']
# ['Isolation']
# ['Good']
# ['Nokia']
# ['Nokia']
# ['Nokia', 'Amazon', 'Amazon Nokia', 'Dekart', 'T', 'Walmart']
# ['C']
# ['China.GPS']
# ['Symbian', 'Pandora']
# ['PERFECT']
# ['Nokia']
# ['Nokia']
# ['Price']
# ['Walnut', 'San Francisco']
# ['Evos', 'Evo', 'Evo Sprint', 'Sprint']
# ['Sprint']
# ['Was', 'Nokia', 'Great']
# ['T', 'T Korea', 'Korean', 'China']
# ['T', 'Email', 'T T']
# ['Applications', 'T', 'Search', 'T T', 'T T T', 'T Windows']
# ['T', 'T Flash', 'Skype']
# ['Touch', 'Droid', 'Froyo', 'Recovery Mode', 'Tasker', 'Yahoo', 'Google', 'Droid Amazon', 'Skype', 'Amazon', 'Nokia', 'Sprint', 'Droid Nokia', 'Galaxy', 'Camera', 'Moto', 'Galaxy Carrier', 'Performance', 'Verizon']
# ['Made']
# ['Nokia']
# ['Europe']
# ['US', 'Amazon', 'Amazon Amazon']
# ['Great']
# ['Nokia']
# ['Nokia', 'Great', 'Wifi', 'Software', 'T']
# ['T', 'T T', 'Password']
# ['N900', 'Otterbox']
# ['Please', 'Media', 'EU', 'Asia']
# ['Google', 'Nokia', 'Android', 'Europe', 'Sprint', 'Google Google', 'Europe Idaho', 'Oregon', 'Amazon', 'C6', 'European', 'C6 N900', 'Europe California', 'US', 'California', 'Nokia Google', 'Google Google Yahoo', 'Symbian', 'Droid', 'Nokia Symbian']
# ['Nokia']
# ['Nokia']
# ['Europe', 'U.S.']
# ['T', 'Great']
# ['Vibrant']
# ['Samsung', 'Nokia', 'X6']
# ['Nokia']
# ['Great', 'Iphone']
# ['South', 'HTML']
# ['Belle', 'Android', 'Belle Nokia']
# ['Lotus']
# ['Russian', 'Android', 'Normal', 'Belle', 'Belle Nokia', 'Nokia', 'Nokia Windows']
# ['Symbian', 'Symbian Windows', 'Symbian Nokia', 'T']
# ['Apple', 'Google', 'Nokia', 'Nokia Symbian Anna']
# ['Symbian']
# ['Symbian', 'Android', 'G2', 'Symbian Symbian', 'Nokia', 'Nokia Nokia', 'Nokia Nokia Belle', 'Belle']
# ['Symbian', 'Symbian Symbian', 'Nokia']
# ['America', 'Nokia', 'Audible']
# ['Nokia', 'Symbian', 'Android', 'Symbian Android', 'Gmail', 'Nokia Symbian', 'U.S.', 'U.S. Nokia', 'Symbian U.S.']
# ['Nokia', 'Ghana']
# ['Nokia', 'GREEN', 'Symbian']
# ['Symbian']
# ['Xenon', 'Anodized', 'Symbian']
# ['Nokia']
# ['Wow']
# ['Panorama', 'Reader', 'Places', 'Mobile', 'Meego', 'Kindle', 'Hulu4', 'Belle', 'Books', 'Meego Symbian', 'Meego Kindle']
# ['Nokia', 'Symbian', 'Nokia Symbian', 'Nokia Nokia']
# ['Symbian', 'Nokia']
# ['Symbian']
# ['Dominican Republic', 'Europe', 'Android', 'Great', 'Blackberry', 'Spanish', 'Symbian']
# ['Nokia', 'Symbian', 'PC-and', 'Swype', 'Symbian Outlook', 'Kindle', 'Nook', 'Symbian Nokia', 'Symbian E71']
# ['Quickly', 'Camera', 'Nokia']
# ['Full', 'Nokia', 'Symbian', 'T', 'Windows', 'Australia']
# ['Nokia']
# ['English', 'Canon', 'China', 'Chienes']
# ['A8183', 'Amazon', 'Great', 'Motorola', 'China', 'Portrait']
# ['N8', 'Nokia', 'Nokia Nokia']
# ['Symbian', 'Nokia', 'Symbian Nokia', 'Android', 'Symbian Belle', 'Nokia India', 'China']
# ['Maemo', 'Symbian OS', 'Symbian']
# ['Bought', 'Nokia']
# ['Solid', 'Symbian', 'Symbian S60', 'N900', 'Google', 'Cyrillic']
# ['Chinese']
# ['Symbian', 'Symbian S60']
# ['Motoblur', 'Orange']
# ['Nokia', 'Mexican', 'South American', 'Spanish', 'Mexico']
# ['S2', 'S']
# ['Vlingo', 'Time', 'Misdial', 'Access', 'Nokia', 'Plantronics']
# ['Edit', 'Nokia']
# ['Turn']
# ['Window']
# ['Jabra']
# ['Bluetooth', 'Plantronics']
# ['Warranty', 'Jabra', 'Jabra Jabra', 'English', 'English Spanish', 'German', 'French', 'Italian', 'Russian', 'Polish', 'Turn']
# ['Us']
# ['Symbian']
# ['U.S.']
# ['Belle', 'Google', 'Sound', 'App', 'Symbian']
# ['UPDATE', 'Nokia', 'Symbian', 'Nokia Nokia', 'Symbian Google', 'Canada', 'Symbian Anna', 'Apple', 'Symbian Symbian']
# ['Symbian', 'Android', 'Motorolas', 'Video', 'Nokia', 'Symbian Symbian', 'Gmail', 'Opera', 'Maps', 'New', 'Exit', 'Symbian Amazon', 'Windows', 'Maemo']
# ['Canada', 'Bahamas', 'Mexico']
# ['Este']
# ['Germany', 'T']
# ['Nokia', 'Calendar', 'Symbian', 'Nokia Amazon', 'Nokia Touchscreen', 'Black']
# ['Symbian']
# ['Israel', 'Camera']
# ['T']
# ['Nokia', 'Symbian', 'Nokia Symbian', 'Symbian Nokia', 'Nokia Nokia', 'Symbian Symbian']
# ['Stylus']
# ['T', 'T T', 'N900', 'Focus']
# ['China']
# ['Nokia']
# ['Spanish', 'Venezuela', 'Movistar']
# ['Amazon']
# ['T']
# ['Palm', 'Verizon', 'Palm Palm']
# ['Swype', 'Amazon', 'Kindle', 'Radio', 'Great', 'Amazon Virgin', 'Tracfone', 'Pack']
# ['Windows', 'Skydive', 'Skype', 'Android', 'Apollo']
# ['Bluetooth']
# ['Nokia']
# ['Nokia', 'T', 'T China', 'China', 'Chinese', 'Chinese Chinese']
# ['Nokia']
# ['Apple', 'Sansa']
# ['Nokia']
# ['Nokia']
# ['Hi']
# ['Nokia', 'Great', 'Atrix']
# ['Bluetooth', 'Bluetooth Amazon', 'Colombia', 'South Smerica']
# ['Nokia']
# ['Kindle', 'Nokia']
# ['Tablet']
# ['New Trent', 'High', 'Notes', 'Apple', 'Nokia']
# ['Kindle', 'Nokia', 'Laptop']
# ['Kindle']
# ['Google', 'Gingerbread']
# ['Got', 'Good']
# ['Fargo', 'Texas12', 'Texas', 'Amazon', 'Texas Dial2Do', 'Facebook', 'Dial2Do']
# ['Joikuspot']
# ['Symbian', 'Symbian Symbian']
# ['NW', 'Belle']
# ['E72', 'Nokia', 'Android', 'Facebook']
# ['Nokia', 'Nokia U.S.', 'U.S.']
# ['Skype']
# ['Nokia', 'Belle']
# ['Ebay', 'Seidio', 'Battery', 'Anker', 'Avatar']
# ['High']
# ['Bluetooth']
# ['T']
# ['UNBOXINGThese']
# ['Montreal', 'Chinese', 'Chinese Japanese', 'Great', 'Seems']
# ['Bose', 'Flacs', 'Sandisk']
# ['Great']
# ['Jabra', 'Bluetooth', 'Outdoor']
# ['English', 'French', 'Portugese', 'Spanish']
# ['Amazon']
# ['Japan', 'American', 'T', 'Starbucks', 'Beijing', 'T Torch', 'Seattle', 'Ebay', 'Gramps', 'Torch', 'T T']
# ['Verizon', 'Pentax', 'Kindle', 'Webtop', 'Sprint', 'T']
# ['Swiss']
# ['Bluetooth', 'Plantronics', 'Bose']
# ['Nokia', 'Plantronics', 'Bose']
# ['Kinivo', 'American', 'Great']
# ['Kinivo']
# ['Sound']
# ['Nokias']
# ['Portable', 'Targus', 'Targus Nokia']
# ['Pandora']
# ['Best', 'Motocast', 'Moto', 'Wifi', 'Action', 'Wifi Motocast', 'Smart', 'Sound', 'Fastest', 'Battery', 'Europe', 'US', 'Android']
# ['Nokia']
# ['Engadget', 'Llama', 'Amazon', 'Male', 'Amazon Kingston', 'Sandisk', 'Sandisk Great', 'Battery']
# ['Photo', 'Tablet']
# ['Overview', 'Glossy', 'English', 'places.-', 'New', 'Notes', 'Nokia']
# ['Playbook', 'Bridge', 'Nokia']
# ['Great']
# ['Kuwait']
# ['Swipe', 'Symbian', 'Europe', 'Asia', 'Symbian Symbian', 'Amazon', 'Indonesia']
# ['Great']
# ['Google', 'Android']
# ['Apple', 'Ipad']
# ['Great']
# ['Verizon', 'Nokia', 'Galaxy']
# ['T', 'Great', 'Nokia']
# ['Nokia', 'Industrial', 'Yelp']
# ['Kindle']
# ['Spanish', 'T', 'Notes']
# ['Focus', 'U.S.']
# ['Belkin']
# ['Nokia']
# ['Android', 'Android Windows']
# ['UPDATE', 'Pin', 'Calendar', 'Email', 'Pictures', 'Camera9', 'Calculator11', 'Marketplace', 'Freec', 'Apps', 'Nokia', 'Skydrive', 'Camera Roll', 'Share', 'Facebook', 'Text', 'Delete']
# ['Meego', 'Nokia']
# ['Nokia', 'Google']
# ['T', 'T T', 'Great', 'Google', 'T Android']
# ['UPDATE', 'Pin', 'Calendar', 'Email', 'Pictures', 'Camera9', 'Calculator11', 'Marketplace', 'Freec', 'Apps', 'Nokia', 'Skydrive', 'Camera Roll', 'Share', 'Facebook', 'Text', 'Delete']
# ['Nokia']
# ['Verizon', 'T', 'Verizon T']
# ['Nokia', 'Montana']
# ['Nokia', 'Samsung', 'Kindle']
# ['Nokia']
# ['Seinfeld']
# ['Nokia']
# ['Belkin']
# ['Incredicharge', 'Incredicharge Incredicharge']
# ['Apple', 'Nokia']
# ['Great']
# ['T']
# ['Overview', 'Glossy', 'Weight', 'Notes', 'Nokia']
# ['Nokia', 'Kindle']
# ['Nokia']
# ['Apple', 'V', 'S', 'X', 'Pro']
# ['T', 'T European', 'Europe']
# ['T', 'Great', 'Google', 'T Android']
# ['Nokia']
# ['Got']
# ['BEWARE', 'Nokia', 'Amazon']
# ['Dad', 'Targus']
# ['Nokia']
# ['German', 'American', 'Japanese']
# ['Amazon', 'Fosmon', 'Ringbo', 'Brunch']
# ['Orange']
# ['Nokia', 'Retail', 'Black']
# ['Satechi', 'S3', 'S2', 'Nokia', 'LG']
# ['Nokia', 'Midwest']
# ['Apple']
# ['T', 'Nokia']
# ['T']
# ['Symbian']
# ['Nokia', 'T', 'T T', 'T T T']
# ['Boston']
# ['Titan', 'Square', 'Rattle', 'Phone', 'T']
# ['Texas', 'New Text']
# ['Samsung']
# ['Nokia', 'T', 'Long Island', 'Android', 'WebOS']
# ['Office']
# ['Facebook']
# ['T', 'Hotmail', 'Android', 'Nokia', 'Inspire']
# ['Balck']
# ['Symbian', 'Nokia']
# ['Stylish', 'Nokia', 'Apollo', 'Newest']
# ['Windows', 'Lumia']
# ['Nokia']
# ['Amazon', 'T']
# ['Titan', 'T']
# ['Nokia']
# ['Great']
# ['Bluetooth', 'Jabra']
# ['Nashville', 'Indiana']
# ['Nokia']
# ['T', 'T Nokia', 'Nokia', 'Google', 'Facebook', 'Tune', 'Radio']
# ['Europe', 'New']
# ['Incredicharge', 'Apple', 'Bluetooth', 'Kindle', 'Kindle Incredicharge']
# ['Incredicharge']
# ['Hawaii', 'Hawaii Nokia', 'Hawaiian']
# ['Anroid']
# ['Nokia']
# ['Glossy', 'Notes', 'Nokia']
# ['Nokia']
# ['Nokia', 'Amazon', 'Great']
# ['Nokia']
# ['Nokia']
# ['Smartphones']
# ['Finland']
# ['T', 'Symbian', 'Maps', 'C', 'Swype', 'Belle']
# ['U.S.A.', 'Apps', 'T']
# ['Nokia', 'Belle', 'Angry', 'T', 'Facebook']
# ['Update', 'STILL', 'Amazon', 'Symbian', 'Belle', 'Symbian E7', 'N8', 'Pureview', 'Nokia', 'Bifrost', 'Nokia Earth', 'Map', 'Nokia Nokia', 'Belle Belle', 'Belle E7', 'N8 N8', 'Tracker', 'Symbian Symbian', 'Belle Belle Belle', 'Symbian Belle', 'Notes', 'Belle Nokia', 'Store', 'Symbian Tmo', 'Greg Corbin', 'Belle Amazon']
# ['Symbian', 'Symbian Symbian', 'Amazon', 'Camera', 'Nokia', 'Nokia T', 'etc.====================================Symbian', 'Dead', 'Symbian Symbian N810', 'Norwegian', 'Symbian Symbian Nokia', 'Symbian Symbian Google', 'Symbian Android', 'Android', 'Android Android', 'Google', 'Symbian Symbian Symbian', 'Symbian Symbian Netflix', 'Amazon Windows', 'Handbrake', 'Nokia Davi', 'T', 'Symbian Symbian Symbian Belle', 'Symbian Endomondo', 'Beta', 'Swype', 'Swype T', 'T Nokia']
# ['Nokia']
# ['Nokia', 'T', 'Sprint']
# ['Florida']
# ['Motorolas', 'Nokias', 'Chicago', 'Galaxy']
# ['Nokia']
# ['Nokia', 'Apple']
# ['Nokia']
# ['Black', 'T']
# ['Nokia']
# ['New Trent', 'High', 'Notes', 'Apple', 'Nokia']
# ['Tablet', 'Powergen']
# ['Laptop', 'Kindle', 'Nokia']
# ['Swiss', 'Droids', 'Nokia', 'Black', 'Retail']
# ['Portable']
# ['Please']
# ['India']
# ['Samsung', 'Motorola', 'LG', 'Nokia']
# ['Ipad']
# ['Again', 'Android', 'Cloud', 'Voice']
# ['Ipad']
# ['Nokia']
# ['Nokia']
# ['Nokias']
# ['UPDATE', 'T']
# ['Black', 'T']
# ['Youtube', 'Vevo']
# ['Nokia']
# ['Got']
# ['Touch', 'Motorola']
# ['S2', 'Rabbit']
# ['Amazon', 'Long', 'T']
# ['Polycarbonate']
# ['Timetec']
# ['Nokia']
# ['California']
# ['Nokia']
# ['Amazon']
# ['Nokia']
# ['Color', 'Nokia']
# ['Buyer']
# ['Great']
# ['Amazon']
# ['Great']
# ['Great']
# ['Motorola']
# ['Everyone']
# ['Nokia']
# ['Asia']
# ['Fits']
# ['India..', 'India']
# ['Launch', 'Sales', 'Qi']
# ['Nokia', 'T', 'Update', 'Good', 'Heavy']
# ['Windows', 'Bluetooth', 'Bluetooth Lumia']
# ['Nokia', 'Finland', 'Chicago', 'Nokia Lumia']
# ['Good']
# ['U.S.', 'T']
# ['Latitude', 'Grams']
# ['Cinematograph']
# ['Nokia', 'T', 'T T']
# ['Android', 'Google', 'Battery', 'Camera']
# ['Amazon']
# ['UPDATE', 'Nokia', 'T', 'Nokia Nokia', 'Nokia Nokia T']
# ['ASIA']
# ['Dundee', 'Canada', 'China', 'Hong Kong', 'Elgin']
# ['Amazon', 'Google', 'Itunes', 'Folder', 'Bluetooth', 'Sportsband', 'Sportsband Bluetooth']
# ['T']
# ['Nokia', 'Apple', 'Exchange', 'Facebook', 'Skype', 'Skype Office', 'Android', 'Apple Nokia', 'Nokia Nokia', 'Nokia Windows']
# ['Amazon', 'T', 'T T']
# ['Nokia', 'T']
# ['Android', 'T']
# ['Amazon', 'T', 'T T']
# ['Nokia']
# ['Facebook']
# ['Nokia', 'Finland', 'Chicago', 'Nokia Lumia']
# ['FLAC', 'MP3', 'Nokia', 'Amazon', 'Google']
# ['Love']
# ['T']
# ['Amazon']
# ['Palm', 'Palm Black', 'Nokia']
# ['Nokia', 'Huawei']
# ['Update', 'Host', 'FAT32', 'Black', 'Retail', 'Google', 'Kindle']
# ['iPhone4also', 'Newest', 'Best']
# ['T', 'Z431']
# ['Nokia']
# ['New']
# ['Nokia']
# ['Swiftkey']
# ['Chinese']
# ['Nokia']
# ['Nokia']
# ['Hulu']
# ['Nokia']
# ['Store']
# ['Cinematograph', 'English', 'Battery', 'Most', 'Mexican', 'English Portuguese']
# ['Note', 'New', 'Thunderbolt', 'Nokia']
# ['Imagine']
# ['Kindle']
# ['Pandora', 'Nokia', 'Amazon', 'Great']
# ['Nokia']
# ['Network', 'Camera']
# ['Whoa', 'Apple']
# ['India']
# ['Silence', 'Symbian']
# ['Black', 'Cyan', 'Lumia', 'Foodspotting', 'Skydrive']
# ['Port2__________Yubi', 'Port1__________Yubi', 'Port2__________Yubi Galaxy', 'Galaxy', 'Galaxy Photo', 'Amazon']
# ['Smartphones']
# ['Six', 'Nokia']
# ['Nokia']
# ['Six', 'Nokia']
# ['Iphone']
# ['T']
# ['Nokia', 'Mapping']
# ['T', 'Las']
# ['Apps', 'San Diego', 'Phone']
# ['Apple', 'Samsung']
# ['Iphone', 'Z10']
# ['Amazon']
# ['Nokia']
# ['Great', 'Camera', 'Pandora']
# ['Nokia', 'Nokia Facebook']
# ['Sleep', 'Native']
# ['T', 'Store', 'Xperia', 'Xperia T', 'T T', 'T T T', 'T Stamina', 'Again', 'Symbian', 'IR', 'Toggle', 'Symbian Nokia', 'Longer', 'Camera', 'Crisper']
# ['Hong Kong', 'Lanyard']
# ['Nokia', 'Speck']
# ['Nokia', 'New Droid', 'Verizon']
# ['Nokia']
# ['Smartphones']
# ['Smartphones']
# ['Power', 'Phone', 'Recharge']
# ['T']
# ['Z10', 'Take']
# ['Nokia']
# ['Great', 'Camera', 'Pandora']
# ['Windows']
# ['Apple', 'Sleep', 'Native']
# ['T']
# ['Great', 'Camera', 'Pandora']
# ['Pros']
# ['Nokia']
# ['Bluetooth']
# ['Nokia', 'Frequency', 'Sound']
# ['Nokia']
# ['Cortana']
# ['Nokia', 'Asian', 'Samsung', 'Call']
# ['Otterbox']
# ['Nokia', 'Beautiful', 'Galaxy']
# ['Fairly', 'Camera']
# ['Capable', 'Nokia', 'U.S.', 'Vietnam']
# ['Windows']
# ['Great']
# ['Garmin', 'Windows', 'Medium', 'Calendar']
# ['Nokia', 'Facebook']
# ['Camera', 'Apps']
# ['Finland', 'European', 'Chinese', 'Quality']
# ['Brought']
# ['Facebook', 'Setup']
# ['Easy']
# ['Amazon']
# ['Swype', 'Least']
# ['Qi', 'Emails', 'Txts', 'IE', 'Caledos']
# ['Apple', 'Instagram']
# ['Iphone', 'Call', 'Windows']
# ['Black', 'Hotspot', 'Nokia', 'Groupon', 'Cinemagraph', 'Nokia Evernote', 'Pinterest', 'Nokia Nokia']
# ['Appearance', 'Apple', 'Windows']
# ['Nokia']
# ['Verizon', 'T']
# ['Lumia', 'Camera', 'Android']
# ['Apps']
# ['Mexico']
# ['Case']
# ['Europe']
# ['Chinese', 'T']
# ['Long']
# ['Work']
# ['Super']
# ['Case']
# ['Nokia']
# ['S3', 'S2', 'I7', 'I9', 'Table']
# ['Iphone', 'Skinomi']
# ['Series', 'New Trent', 'New']
# ['Dad']
# ['Kickstand']
# ['Length', 'Port', 'Fastest', 'S3', 'S2', 'S']
# ['Bolse', 'Blackberry', 'Nokia']
# ['Beautiful', 'Swivel']
# ['Amazon']
# ['Airplane']
# ['Poetic']
# ['Nokia', 'T']
# ['Nokia']
# ['Bought']
# ['T', 'Belkin', 'Great']
# ['Disclosure', 'England', 'British']
# ['Google', 'Nokia', 'Great']
# ['Samsung', 'Nokia']
# ['Qi', 'Easy', 'Durable', 'Bright']
# ['Battery', 'S']
# ['Nokia']
# ['T', 'Nokia', 'Nokia Nokia']
# ['Nokia']
# ['Nokia']
# ['Series', 'New Trent', 'Velcro']
# ['H721']
# ['Port', 'New', 'Can', 'Anker']
# ['Ikea', 'Ankers']
# ['T', 'Nokia']
# ['Nokia']
# ['Camera', 'Call']
# ['T', 'Photosynth', 'T T', 'Xenon', 'Amazon']
# ['T', 'Nokia', 'T T']
# ['Nokia']
# ['Apple']
# ['Update', 'Camera', 'Call']
# ['Facebook', 'Evernote', 'Podcast']
# ['T', 'Nokia', 'Kindle', 'T Android', 'QR']
# ['UI', 'Nokia']
# ['T', 'Nokia']
# ['Anker']
# ['Lumina', 'Nokia']
# ['Apple', 'Nokia']
# ['Kindle', 'Nokia']
# ['Nokia']
# ['Bolse']
# ['Nokia', 'Samsung']
# ['Amazon']
# ['Nokia']
# ['Power', 'Phone', 'Travel', 'S3', 'S2', 'Nexus', 'Thunderbolt', 'Incredible', 'Droid']
# ['Sansa']
# ['United States', 'Lithium', 'Great']
# ['Nokia']
# ['Dual', 'S3', 'S2', 'Nexus', 'Thunderbolt', 'Incredible', 'Droid', 'Portable']
# ['Fashionable', 'Power', 'Phone', 'Travel', 'S3', 'S2', 'Nexus', 'Thunderbolt', 'Incredible', 'Droid']
# ['Sansa', 'English']
# ['Amazon', 'Nokia', 'Microsoft', 'Illumishield']
# ['Great', 'America']
# ['Nokia']
# ['American', 'T', 'T T']
# ['T', 'T Offline', 'Kindle', 'Power']
# ['Bought', 'Vietnam']
# ['T', 'Facebook']
# ['Access', 'T']
# ['Arizona', 'Nokia']
# ['T', 'T T']
# ['Excel']
# ['T', 'Settings', 'Settings Microsoft', 'Nokia', 'Store', 'Settings Kindle', 'Settings Store', 'Kindle', 'Dublin', 'Nokia T', 'T Kindle']
# ['Google', 'Nokia']
# ['Skype', 'T', 'Windows', 'Windows Malwarebytes']
# ['Everyone', 'T', 'Nokia']
# ['Nokia']
# ['Nokia']
# ['Amazon', 'Apple']
# ['Droid', 'Gnex', 'Home', 'Task', 'Gingerbread', 'Google', 'Android', 'Sense', 'Motoblur', 'Astro', 'Google Play', 'Nokia', 'Verizon', 'Swype', 'Pandora', 'Strength', 'Motorola', 'Google Verizon']
# ['Awesome']
# ['Lumia']
# ['Medium', 'Nokia', 'Amazon']
# ['Tablet', 'Next']
# ['S3', 'S2', 'Thunderbolt', 'Incredible', 'Droid', 'Apple', 'Nokia']
# ['Nokia']
# ['Nokia']
# ['Great', 'Call', 'Anker']
# ['Fatboy', 'Amazon']
# ['Belkin', 'Kindle']
# ['Nokia']
# ['Sharkk', 'Southfield']
# ['Messaging', 'Amazon', 'Freecell', 'Apple', 'T', 'T Facebook']
# ['Nothing']
# ['Nokia']
# ['Apple', 'Motorola', 'Korean']
# ['Galaxy']
# ['T', 'Speech', 'Kindle']
# ['T', 'Speech', 'Kindle']
# ['dual-band', 'S4', 'Galaxy', 'Galaxy Retail', 'Nexus', 'Garmin', 'News', 'Android', 'Quad']
# ['Galaxy']
# ['Papyrus', 'Google']
# ['T', 'Nokia']
# ['Nokia']
# ['Simple']
# ['Quite']
# ['Asia']
# ['Kindle', 'Kindle Sprint', 'Nokia']
# ['Every', 'Male', 'Sprint', 'Nokia']
# ['Nokia']
# ['Acer']
# ['Kindle']
# ['Beware']
# ['Nokia', 'Amazon', 'Thank']
# ['Nokia', 'More']
# ['Kindle']
# ['Nokia']
# ['S3', 'S2', 'Raider', 'Legend', 'Flyer']
# ['Kindle', 'Kindle Kindle', 'V', 'S', 'T', 'Torch']
# ['Ebay']
# ['Great']
# ['Screen']
# ['T', 'T T']
# ['New', 'Arcadia']
# ['New', 'Amazon']
# ['Camera', 'New']
# ['Philips']
# ['Nokia', 'Apple', 'Windows']
# ['Photostream', 'News', 'Windows']
# ['Verizon', 'T', 'Camera']
# ['Easyacc']
# ['Apple', 'Beauty']
# ['Apple', 'Beauty', 'Awesome', 'Apple Fantastic']
# ['Apple', 'Beauty']
# ['Samsung']
# ['T', 'Fosmon']
# ['Durable', 'Price', 'Fast']
# ['Anker']
# ['Durable', 'Price', 'Fast']
# ['Logitech']
# ['Nokia']
# ['T']
# ['Good', 'Google']
# ['Orbit', 'Orbit Overall', 'Portable', 'Wasn']
# ['Port']
# ['Galaxy']
# ['Lenova']
# ['Nokia']
# ['Good']
# ['Long']
# ['Nokia', 'Android']
# ['S4', 'WP', 'Android', 'Xbox', 'Spotify']
# ['Nokia', 'United States']
# ['W8', 'Google', 'European', 'American', 'Nokia', 'GPS']
# ['Venue', 'Great']
# ['Quality', 'Apps', 'Yellow', 'Green', 'Huge']
# ['New', 'Droid', 'Touch', 'Torch', 'Tour']
# ['United', 'T', 'Macs', 'Lenovo', 'T T', 'U.S.', 'T T United']
# ['Nokia']
# ['Great']
# ['S3', 'S2']
# ['Nokia']
# ['Stylish', 'Power', 'Phone', 'User', 'S3', 'S2', 'Nexus', 'Thunderbolt', 'Incredible', 'Droid']
# ['H', 'Anker', 'Great']
# ['Power', 'Kindle', 'Tablets']
# ['Nokia']
# ['S', 'V', 'S T', 'T', 'T X10Motorola', 'V S']
# ['Good', 'Camera']
# ['Verizon', 'Camera', 'Apple', 'Nokia', 'Clear', 'Cortana']
# ['Chicago', 'Facebook', 'Facebook Google', 'Icon', 'Nokia']
# ['New', 'Nokia']
# ['New iPad']
# ['Travel', 'Recharge']
# ['Apple']
# ['Windows']
# ['Symbian', 'Z1', 'Tmobile', 'Tmobil', 'Free']
# ['Apple']
# ['English', 'Spanish', 'French']
# ['Anker', 'Sabrent', 'English']
# ['Belkin']
# ['Must']
# ['Quad', 'Android', 'Manual', 'Face', 'Exposure', 'White', 'Burst', 'Panorama', 'Macro', 'News']
# ['Nokia', 'Xperia', 'Nokia Nokia', 'Facebook']
# ['Verizon', 'M8', 'Sense', 'Zoom']
# ['Nokia', 'Xperia', 'Nokia Nokia', 'Facebook']
# ['Verizon', 'M8', 'Sense', 'Zoom']
# ['S4', 'Quad', 'S5', 'Galaxy', 'S5 Infrared', 'Garmin', 'News', 'Ebay', 'Tapatalk', 'Android']
# ['Galaxy', 'Africa']
# ['Setup1']
# ['Pebble', 'Feedly', 'Banjo', 'Expedia', 'Evernote', 'Feedly Paypal', 'Call', 'Tizen', 'Anroid']
# ['Pebble', 'Feedly', 'Banjo', 'Expedia', 'Evernote', 'Feedly Paypal', 'Call', 'Tizen', 'Anroid']
# ['Nokia']
# ['Nokia', 'China.A']
# ['Nokia']
# ['Nokia']
# ['Eachine', 'Nokia']
# ['Nokia']
# ['Nokia']
# ['Kindle']
# ['Nokia', 'Xperia', 'Nokia Nokia', 'Facebook']
# ['Mini', 'S3', 'S2', 'Headsets']

# %%
cursor = db.reviews.find({"reviewText": regx}, {"reviewText": 1, "keywords":1,"GPEs":1})

for e in cursor:
    if e['GPEs']:
        print(e['GPEs'])
# Out:
# ['Verizon', 'Ericsson', 'Nokia']
# ['Europe']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-08066430718d> in <module>()
#       2
#       3 for e in cursor:
# ----> 4     if e['GPEs']:
#       5         print(e['GPEs'])
#
# KeyError: 'GPEs'
